# %% [markdown]
# <a href="https://colab.research.google.com/github/NitishaS-812k/comet/blob/master/comet_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Copyright (c) 2019, Adobe Inc. All rights reserved.
#
# This work is licensed under the Creative Commons Attribution-NonCommercial-ShareAlike
# 4.0 International Public License. To view a copy of this license, visit
# https://creativecommons.org/licenses/by-nc-sa/4.0/legalcode.

import torch
import torch.nn.parallel
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from IPython import embed

class Downsample(nn.Module):
    def __init__(self, pad_type='reflect', filt_size=3, stride=2, channels=None, pad_off=0):
        super(Downsample, self).__init__()
        self.filt_size = filt_size
        self.pad_off = pad_off
        self.pad_sizes = [int(1.*(filt_size-1)/2), int(np.ceil(1.*(filt_size-1)/2)), int(1.*(filt_size-1)/2), int(np.ceil(1.*(filt_size-1)/2))]
        self.pad_sizes = [pad_size+pad_off for pad_size in self.pad_sizes]
        self.stride = stride
        self.off = int((self.stride-1)/2.)
        self.channels = channels

        if(self.filt_size==1):
            a = np.array([1.,])
        elif(self.filt_size==2):
            a = np.array([1., 1.])
        elif(self.filt_size==3):
            a = np.array([1., 2., 1.])
        elif(self.filt_size==4):
            a = np.array([1., 3., 3., 1.])
        elif(self.filt_size==5):
            a = np.array([1., 4., 6., 4., 1.])
        elif(self.filt_size==6):
            a = np.array([1., 5., 10., 10., 5., 1.])
        elif(self.filt_size==7):
            a = np.array([1., 6., 15., 20., 15., 6., 1.])

        filt = torch.Tensor(a[:,None]*a[None,:])
        filt = filt/torch.sum(filt)
        self.register_buffer('filt', filt[None,None,:,:].repeat((self.channels,1,1,1)))

        self.pad = get_pad_layer(pad_type)(self.pad_sizes)

    def forward(self, inp):
        if(self.filt_size==1):
            if(self.pad_off==0):
                return inp[:,:,::self.stride,::self.stride]
            else:
                return self.pad(inp)[:,:,::self.stride,::self.stride]
        else:
            return F.conv2d(self.pad(inp), self.filt, stride=self.stride, groups=inp.shape[1])

def get_pad_layer(pad_type):
    if(pad_type in ['refl','reflect']):
        PadLayer = nn.ReflectionPad2d
    elif(pad_type in ['repl','replicate']):
        PadLayer = nn.ReplicationPad2d
    elif(pad_type=='zero'):
        PadLayer = nn.ZeroPad2d
    else:
        print('Pad type [%s] not recognized'%pad_type)
    return PadLayer

class Downsample1D(nn.Module):
    def __init__(self, pad_type='reflect', filt_size=3, stride=2, channels=None, pad_off=0):
        super(Downsample1D, self).__init__()
        self.filt_size = filt_size
        self.pad_off = pad_off
        self.pad_sizes = [int(1. * (filt_size - 1) / 2), int(np.ceil(1. * (filt_size - 1) / 2))]
        self.pad_sizes = [pad_size + pad_off for pad_size in self.pad_sizes]
        self.stride = stride
        self.off = int((self.stride - 1) / 2.)
        self.channels = channels

        # print('Filter size [%i]' % filt_size)
        if(self.filt_size == 1):
            a = np.array([1., ])
        elif(self.filt_size == 2):
            a = np.array([1., 1.])
        elif(self.filt_size == 3):
            a = np.array([1., 2., 1.])
        elif(self.filt_size == 4):
            a = np.array([1., 3., 3., 1.])
        elif(self.filt_size == 5):
            a = np.array([1., 4., 6., 4., 1.])
        elif(self.filt_size == 6):
            a = np.array([1., 5., 10., 10., 5., 1.])
        elif(self.filt_size == 7):
            a = np.array([1., 6., 15., 20., 15., 6., 1.])

        filt = torch.Tensor(a)
        filt = filt / torch.sum(filt)
        self.register_buffer('filt', filt[None, None, :].repeat((self.channels, 1, 1)))

        self.pad = get_pad_layer_1d(pad_type)(self.pad_sizes)

    def forward(self, inp):
        if(self.filt_size == 1):
            if(self.pad_off == 0):
                return inp[:, :, ::self.stride]
            else:
                return self.pad(inp)[:, :, ::self.stride]
        else:
            return F.conv1d(self.pad(inp), self.filt, stride=self.stride, groups=inp.shape[1])

def get_pad_layer_1d(pad_type):
    if(pad_type in ['refl', 'reflect']):
        PadLayer = nn.ReflectionPad1d
    elif(pad_type in ['repl', 'replicate']):
        PadLayer = nn.ReplicationPad1d
    elif(pad_type == 'zero'):
        PadLayer = nn.ZeroPad1d
    else:
        print('Pad type [%s] not recognized' % pad_type)
    return PadLayer

# %%
from torch.nn import ModuleList
import torch.nn.functional as F
import torch.nn as nn
import torch
from easydict import EasyDict

def swish(x):
    return x * torch.sigmoid(x)

class View(nn.Module):
    def __init__(self, size):
        super(View, self).__init__()
        self.size = size

    def forward(self, tensor):
        return tensor.view(self.size)


def kaiming_init(m):
    if isinstance(m, (nn.Linear, nn.Conv2d)):
        torch.nn.init.kaiming_normal(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0)
    elif isinstance(m, (nn.BatchNorm1d, nn.BatchNorm2d)):
        m.weight.data.fill_(1)
        if m.bias is not None:
            m.bias.data.fill_(0)


def reparametrize(mu, logvar):
    std = logvar.div(2).exp()
    eps = torch.autograd.Variable(std.data.new(std.size()).normal_())
    return mu + std*eps



class Self_Attn(nn.Module):
    """ Self attention Layer"""
    def __init__(self,in_dim,activation):
        super(Self_Attn,self).__init__()
        self.chanel_in = in_dim
        self.activation = activation

        self.query_conv = nn.Conv2d(in_channels = in_dim , out_channels = in_dim//8 , kernel_size= 1)
        self.key_conv = nn.Conv2d(in_channels = in_dim , out_channels = in_dim//8 , kernel_size= 1)
        self.value_conv = nn.Conv2d(in_channels = in_dim , out_channels = in_dim , kernel_size= 1)
        self.gamma = nn.Parameter(torch.zeros(1))

        self.softmax  = nn.Softmax(dim=-1) #

    def forward(self,x):
        """
            inputs :
                x : input feature maps( B X C X W X H)
            returns :
                out : self attention value + input feature
                attention: B X N X N (N is Width*Height)
        """
        m_batchsize,C,width ,height = x.size()
        proj_query  = self.query_conv(x).view(m_batchsize,-1,width*height).permute(0,2,1) # B X CX(N)
        proj_key =  self.key_conv(x).view(m_batchsize,-1,width*height) # B X C x (*W*H)
        energy =  torch.bmm(proj_query,proj_key) # transpose check
        attention = self.softmax(energy) # BX (N) X (N)
        proj_value = self.value_conv(x).view(m_batchsize,-1,width*height) # B X C X N

        out = torch.bmm(proj_value,attention.permute(0,2,1) )
        out = out.view(m_batchsize,C,width,height)

        out = self.gamma*out + x
        return out,attention


class CondResBlock(nn.Module):
    def __init__(self, downsample=True, rescale=True, filters=64, latent_dim=64, im_size=64, latent_grid=False):
        super(CondResBlock, self).__init__()

        self.filters = filters
        self.latent_dim = latent_dim
        self.im_size = im_size
        self.downsample = downsample
        self.latent_grid = latent_grid

        if filters <= 128:
            self.bn1 = nn.InstanceNorm2d(filters, affine=False)
        else:
            self.bn1 = nn.GroupNorm(32, filters, affine=False)

        self.conv1 = nn.Conv2d(filters, filters, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(filters, filters, kernel_size=3, stride=1, padding=1)

        if filters <= 128:
            self.bn2 = nn.InstanceNorm2d(filters, affine=False)
        else:
            self.bn2 = nn.GroupNorm(32, filters, affine=False)


        torch.nn.init.normal_(self.conv2.weight, mean=0.0, std=1e-5)

        # Upscale to an mask of image
        self.latent_fc1 = nn.Linear(latent_dim, 2*filters)
        self.latent_fc2 = nn.Linear(latent_dim, 2*filters)

        # Upscale to mask of image
        if downsample:
            if rescale:
                self.conv_downsample = nn.Conv2d(filters, 2 * filters, kernel_size=3, stride=1, padding=1)
            else:
                self.conv_downsample = nn.Conv2d(filters, filters, kernel_size=3, stride=1, padding=1)

            self.avg_pool = nn.AvgPool2d(3, stride=2, padding=1)

    def forward(self, x, latent):
        x_orig = x

        latent_1 = self.latent_fc1(latent)
        latent_2 = self.latent_fc2(latent)

        gain = latent_1[:, :self.filters, None, None]
        bias = latent_1[:, self.filters:, None, None]

        gain2 = latent_2[:, :self.filters, None, None]
        bias2 = latent_2[:, self.filters:, None, None]

        x = self.conv1(x)
        x = gain * x + bias
        x = swish(x)


        x = self.conv2(x)
        x = gain2 * x + bias2
        x = swish(x)

        x_out = x_orig + x

        if self.downsample:
            x_out = swish(self.conv_downsample(x_out))
            x_out = self.avg_pool(x_out)

        return x_out


class CondResBlockNoLatent(nn.Module):
    def __init__(self, downsample=True, rescale=True, filters=64, upsample=False):
        super(CondResBlockNoLatent, self).__init__()

        self.filters = filters
        self.downsample = downsample

        if filters <= 128:
            self.bn1 = nn.GroupNorm(int(32  * filters / 128), filters, affine=True)
        else:
            self.bn1 = nn.GroupNorm(32, filters, affine=False)

        self.conv1 = nn.Conv2d(filters, filters, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(filters, filters, kernel_size=3, stride=1, padding=1)

        if filters <= 128:
            self.bn2 = nn.GroupNorm(int(32 * filters / 128), filters, affine=True)
        else:
            self.bn2 = nn.GroupNorm(32, filters, affine=True)

        self.upsample = upsample
        self.upsample_module = nn.Upsample(scale_factor=2)
        # Upscale to mask of image
        if downsample:
            if rescale:
                self.conv_downsample = nn.Conv2d(filters, 2 * filters, kernel_size=3, stride=1, padding=1)
            else:
                self.conv_downsample = nn.Conv2d(filters, filters, kernel_size=3, stride=1, padding=1)

            self.avg_pool = nn.AvgPool2d(3, stride=2, padding=1)

        if upsample:
            self.conv_downsample = nn.Conv2d(filters, filters, kernel_size=3, stride=1, padding=1)

    def forward(self, x):
        x_orig = x


        x = self.conv1(x)
        x = swish(x)

        x = self.conv2(x)
        x = swish(x)

        x_out = x_orig + x

        if self.upsample:
            x_out = self.upsample_module(x_out)
            x_out = swish(self.conv_downsample(x_out))

        if self.downsample:
            x_out = swish(self.conv_downsample(x_out))
            x_out = self.avg_pool(x_out)

        return x_out


class BroadcastConvDecoder(nn.Module):
    def __init__(self, im_size, latent_dim):
        super().__init__()
        self.im_size = im_size + 8
        self.latent_dim = latent_dim
        self.init_grid()

        self.g = nn.Sequential(
                    nn.Conv2d(self.latent_dim+2, 32, 3, 1, 0),
                    nn.ReLU(True),
                    nn.Conv2d(32, 32, 3, 1, 0),
                    nn.ReLU(True),
                    nn.Conv2d(32, 32, 3, 1, 0),
                    nn.ReLU(True),
                    nn.Conv2d(32, 32, 3, 1, 0),
                    nn.ReLU(True),
                    nn.Conv2d(32, self.latent_dim, 1, 1, 0)
                    )

    def init_grid(self):
        x = torch.linspace(0, 1, self.im_size)
        y = torch.linspace(0, 1, self.im_size)
        self.x_grid, self.y_grid = torch.meshgrid(x, y)


    def broadcast(self, z):
        b = z.size(0)
        x_grid = self.x_grid.expand(b, 1, -1, -1).to(z.device)
        y_grid = self.y_grid.expand(b, 1, -1, -1).to(z.device)
        z = z.view((b, -1, 1, 1)).expand(-1, -1, self.im_size, self.im_size)
        z = torch.cat((z, x_grid, y_grid), dim=1)
        return z

    def forward(self, z):
        z = self.broadcast(z)
        x = self.g(z)
        return x


class LatentEBM128(nn.Module):
    def __init__(self, args, dataset):
        super(LatentEBM128, self).__init__()

        filter_dim = args.filter_dim
        self.filter_dim = filter_dim
        latent_dim_expand = args.latent_dim * args.components
        latent_dim = args.latent_dim

        self.components = args.components

        n_instance = len(dataset)
        self.pos_embed = args.pos_embed

        if self.pos_embed:
            self.conv1 = nn.Conv2d(3, filter_dim // 2, kernel_size=3, stride=1, padding=1, bias=True)
            self.conv1_embed = nn.Conv2d(2, filter_dim // 2, kernel_size=3, stride=1, padding=1, bias=True)
        else:
            self.conv1 = nn.Conv2d(3, filter_dim // 4, kernel_size=3, stride=1, padding=1, bias=True)
        self.avg_pool = nn.AvgPool2d(3, stride=2, padding=1)

        self.gain = nn.Linear(args.latent_dim, filter_dim // 4)
        self.bias = nn.Linear(args.latent_dim, filter_dim // 4)

        self.recurrent_model = args.recurrent_model

        if args.dataset == "tetris":
            self.im_size = 35
        else:
            self.im_size = 64

        self.layer_encode = CondResBlock(filters=filter_dim//4, latent_dim=latent_dim, rescale=True)
        self.layer1 = CondResBlock(filters=filter_dim//2, latent_dim=latent_dim, rescale=True)
        self.layer2 = CondResBlock(filters=filter_dim, latent_dim=latent_dim, rescale=False)
        self.layer3 = CondResBlock(filters=filter_dim, latent_dim=latent_dim, rescale=False)
        self.layer4 = CondResBlock(filters=filter_dim, latent_dim=latent_dim)
        self.mask_decode = BroadcastConvDecoder(64, latent_dim)

        self.latent_map = nn.Linear(latent_dim, filter_dim * 8)
        self.energy_map = nn.Linear(filter_dim * 2, 1)

        self.embed_conv1 = nn.Conv2d(3, filter_dim, kernel_size=3, stride=1, padding=1)
        self.embed_layer1 = CondResBlockNoLatent(filters=filter_dim, rescale=False, downsample=True)
        self.embed_layer2 = CondResBlockNoLatent(filters=filter_dim, rescale=False, downsample=True)
        self.embed_layer3 = CondResBlockNoLatent(filters=filter_dim, rescale=False, downsample=True)

        self.decode_layer1 = CondResBlockNoLatent(filters=filter_dim, rescale=False, upsample=True, downsample=False)
        self.decode_layer2 = CondResBlockNoLatent(filters=filter_dim, rescale=False, upsample=True, downsample=False)
        self.decode_layer3 = CondResBlockNoLatent(filters=filter_dim, rescale=False, upsample=True, downsample=False)

        self.latent_decode = nn.Conv2d(filter_dim, latent_dim_expand, kernel_size=3, stride=1, padding=1)

        self.downsample = Downsample(channels=args.latent_dim)
        self.dataset = args.dataset

        if self.recurrent_model:
            self.embed_layer4 = CondResBlockNoLatent(filters=filter_dim, rescale=False, downsample=True)
            self.lstm = nn.LSTM(filter_dim, filter_dim, 1)
            self.embed_fc2 = nn.Linear(filter_dim, latent_dim)

            self.at_fc1 = nn.Linear(filter_dim*2, filter_dim)
            self.at_fc2 = nn.Linear(filter_dim, 1)

            self.map_embed = nn.Linear(filter_dim*2, filter_dim)

            if args.dataset == "tetris":
                self.pos_embedding = nn.Parameter(torch.zeros(9, filter_dim))
            else:
                self.pos_embedding = nn.Parameter(torch.zeros(16, filter_dim))
        else:
            self.embed_fc1 = nn.Linear(filter_dim, filter_dim)
            self.embed_fc2 = nn.Linear(filter_dim, latent_dim_expand)

        self.init_grid()

    def gen_mask(self, latent):
        return self.mask_decode(latent)

    def init_grid(self):
        x = torch.linspace(0, 1, self.im_size)
        y = torch.linspace(0, 1, self.im_size)
        self.x_grid, self.y_grid = torch.meshgrid(x, y)

    def embed_latent(self, im):
        x = self.embed_conv1(im)
        x = F.relu(x)
        x = self.embed_layer1(x)
        x = self.embed_layer2(x)
        x = self.embed_layer3(x)

        if self.recurrent_model:

            #if self.dataset != "clevr":
            x = self.embed_layer4(x)

            s = x.size()
            x = x.view(s[0], s[1], -1)
            x = x.permute(0, 2, 1).contiguous()
            pos_embed = self.pos_embedding

            # x = x + pos_embed[None, :, :]
            h = torch.zeros(1, im.size(0), self.filter_dim).to(x.device), torch.zeros(1, im.size(0), self.filter_dim).to(x.device)
            outputs = []

            for i in range(self.components):
                (sx, cx) = h

                cx = cx.permute(1, 0, 2).contiguous()
                context = torch.cat([cx.expand(-1, x.size(1), -1), x], dim=-1)
                at_wt = self.at_fc2(F.relu(self.at_fc1(context)))
                at_wt = F.softmax(at_wt, dim=1)
                inp = (at_wt * context).sum(dim=1, keepdim=True)
                inp = self.map_embed(inp)
                inp = inp.permute(1, 0, 2).contiguous()

                output, h = self.lstm(inp, h)
                outputs.append(output)

            output = torch.cat(outputs, dim=0)
            output = output.permute(1, 0, 2).contiguous()
            output = self.embed_fc2(output)
            s = output.size()
            output = output.view(s[0], -1)
        else:
            x = x.mean(dim=2).mean(dim=2)

            x = x.view(x.size(0), -1)
            output = self.embed_fc1(x)
            x = F.relu(self.embed_fc1(x))
            output = self.embed_fc2(x)

        return output

    def forward(self, x, latent):

        if self.pos_embed:
            b = x.size(0)
            x_grid = self.x_grid.expand(b, 1, -1, -1).to(x.device)
            y_grid = self.y_grid.expand(b, 1, -1, -1).to(x.device)
            coord_grid = torch.cat([x_grid, y_grid], dim=1)

        inter = self.conv1(x)
        inter = swish(inter)

        if self.pos_embed:
            pos_inter = self.conv1_embed(coord_grid)
            pos_inter = swish(pos_inter)

            inter = torch.cat([inter, pos_inter], dim=1)


        x = self.layer_encode(inter, latent)
        x = self.layer1(x, latent)


        x = self.layer2(x, latent)
        x = self.layer3(x, latent)
        x = self.layer4(x, latent)

        x = x.mean(dim=2).mean(dim=2)
        x = x.view(x.size(0), -1)

        energy = self.energy_map(x)

        return energy


class LatentEBM(nn.Module):
    def __init__(self, args, dataset):
        super(LatentEBM, self).__init__()

        filter_dim = args.filter_dim
        self.filter_dim = filter_dim
        latent_dim_expand = args.latent_dim * args.components
        latent_dim = args.latent_dim

        self.components = args.components

        n_instance = len(dataset)
        self.pos_embed = args.pos_embed

        if self.pos_embed:
            self.conv1 = nn.Conv2d(3, filter_dim // 2, kernel_size=3, stride=1, padding=1, bias=True)
            self.conv1_embed = nn.Conv2d(2, filter_dim // 2, kernel_size=3, stride=1, padding=1, bias=True)
        else:
            self.conv1 = nn.Conv2d(3, filter_dim, kernel_size=3, stride=1, padding=1, bias=True)

        self.avg_pool = nn.AvgPool2d(3, stride=2, padding=1)

        self.gain = nn.Linear(args.latent_dim, filter_dim)
        self.bias = nn.Linear(args.latent_dim, filter_dim)

        self.recurrent_model = args.recurrent_model

        if args.dataset == "tetris":
            self.im_size = 35
        else:
            self.im_size = 64

        self.layer_encode = CondResBlock(filters=filter_dim, latent_dim=latent_dim, rescale=False)
        self.layer1 = CondResBlock(filters=filter_dim, latent_dim=latent_dim, rescale=False)
        self.layer2 = CondResBlock(filters=filter_dim, latent_dim=latent_dim)
        self.mask_decode = BroadcastConvDecoder(64, latent_dim)

        self.latent_map = nn.Linear(latent_dim, filter_dim * 8)
        self.energy_map = nn.Linear(filter_dim * 2, 1)

        self.embed_conv1 = nn.Conv2d(3, filter_dim, kernel_size=3, stride=1, padding=1)
        self.embed_layer1 = CondResBlockNoLatent(filters=filter_dim, rescale=False, downsample=True)
        self.embed_layer2 = CondResBlockNoLatent(filters=filter_dim, rescale=False, downsample=True)
        self.embed_layer3 = CondResBlockNoLatent(filters=filter_dim, rescale=False, downsample=True)

        self.decode_layer1 = CondResBlockNoLatent(filters=filter_dim, rescale=False, upsample=True, downsample=False)
        self.decode_layer2 = CondResBlockNoLatent(filters=filter_dim, rescale=False, upsample=True, downsample=False)
        self.decode_layer3 = CondResBlockNoLatent(filters=filter_dim, rescale=False, upsample=True, downsample=False)

        self.latent_decode = nn.Conv2d(filter_dim, latent_dim_expand, kernel_size=3, stride=1, padding=1)

        self.downsample = Downsample(channels=args.latent_dim)
        self.dataset = args.dataset

        if self.recurrent_model:
            self.embed_layer4 = CondResBlockNoLatent(filters=filter_dim, rescale=False, downsample=True)
            self.lstm = nn.LSTM(filter_dim, filter_dim, 1)
            self.embed_fc2 = nn.Linear(filter_dim, latent_dim)

            self.at_fc1 = nn.Linear(filter_dim*2, filter_dim)
            self.at_fc2 = nn.Linear(filter_dim, 1)

            self.map_embed = nn.Linear(filter_dim*2, filter_dim)

            if args.dataset == "tetris":
                self.pos_embedding = nn.Parameter(torch.zeros(9, filter_dim))
            else:
                self.pos_embedding = nn.Parameter(torch.zeros(16, filter_dim))
        else:
            self.embed_fc1 = nn.Linear(filter_dim, filter_dim)
            self.embed_fc2 = nn.Linear(filter_dim, latent_dim_expand)

        self.init_grid()

    def gen_mask(self, latent):
        return self.mask_decode(latent)

    def init_grid(self):
        x = torch.linspace(0, 1, self.im_size)
        y = torch.linspace(0, 1, self.im_size)
        self.x_grid, self.y_grid = torch.meshgrid(x, y)

    def embed_latent(self, im):
        x = self.embed_conv1(im)
        x = F.relu(x)
        x = self.embed_layer1(x)
        x = self.embed_layer2(x)
        x = self.embed_layer3(x)

        if self.recurrent_model:

            x = self.embed_layer4(x)

            s = x.size()
            x = x.view(s[0], s[1], -1)
            x = x.permute(0, 2, 1).contiguous()

            h = torch.zeros(1, im.size(0), self.filter_dim).to(x.device), torch.zeros(1, im.size(0), self.filter_dim).to(x.device)
            outputs = []

            for i in range(self.components):
                (sx, cx) = h

                cx = cx.permute(1, 0, 2).contiguous()
                context = torch.cat([cx.expand(-1, x.size(1), -1), x], dim=-1)
                at_wt = self.at_fc2(F.relu(self.at_fc1(context)))
                at_wt = F.softmax(at_wt, dim=1)
                inp = (at_wt * context).sum(dim=1, keepdim=True)
                inp = self.map_embed(inp)
                inp = inp.permute(1, 0, 2).contiguous()

                output, h = self.lstm(inp, h)
                outputs.append(output)

            output = torch.cat(outputs, dim=0)
            output = output.permute(1, 0, 2).contiguous()
            output = self.embed_fc2(output)
            s = output.size()
            output = output.view(s[0], -1)
        else:
            x = x.mean(dim=2).mean(dim=2)

            x = x.view(x.size(0), -1)
            output = self.embed_fc1(x)
            x = F.relu(self.embed_fc1(x))
            output = self.embed_fc2(x)

        return output

    def forward(self, x, latent):

        if self.pos_embed:
            b = x.size(0)
            x_grid = self.x_grid.expand(b, 1, -1, -1).to(x.device)
            y_grid = self.y_grid.expand(b, 1, -1, -1).to(x.device)
            coord_grid = torch.cat([x_grid, y_grid], dim=1)

        # x = x.contiguous()
        inter = self.conv1(x)
        inter = swish(inter)

        if self.pos_embed:
            pos_inter = self.conv1_embed(coord_grid)
            pos_inter = swish(pos_inter)

            inter = torch.cat([inter, pos_inter], dim=1)

        x = self.avg_pool(inter)

        x = self.layer_encode(x, latent)

        x = self.layer1(x, latent)
        x = self.layer2(x, latent)

        x = x.mean(dim=2).mean(dim=2)
        x = x.view(x.size(0), -1)

        energy = self.energy_map(x)

        return energy

class ToyEBM(nn.Module):
    def __init__(self, args, dataset):
        super(ToyEBM, self).__init__()

        filter_dim = args.filter_dim
        latent_dim_expand = args.latent_dim * args.components
        latent_dim = args.latent_dim
        im_size = 64

        n_instance = len(dataset)

        self.conv1 = nn.Conv2d(3, filter_dim, kernel_size=3, stride=1, padding=1, bias=True)
        self.avg_pool = nn.AvgPool2d(3, stride=2, padding=1)
        self.layer_encode = CondResBlock(filters=filter_dim, latent_dim=latent_dim, rescale=False)
        self.layer1 = CondResBlock(filters=filter_dim, latent_dim=latent_dim, rescale=False)
        self.layer2 = CondResBlock(filters=filter_dim, latent_dim=latent_dim)


        self.fc1 = nn.Linear(filter_dim * 2, filter_dim * 2)

        self.latent_map = nn.Linear(latent_dim, filter_dim * 8)
        self.energy_map = nn.Linear(filter_dim * 2, 1)

        self.embed_conv1 = nn.Conv2d(3, filter_dim, kernel_size=5, stride=2, padding=3)
        self.embed_layer1 = CondResBlockNoLatent(filters=filter_dim, rescale=False)
        self.embed_layer2 = CondResBlockNoLatent(filters=filter_dim)
        self.embed_fc1 = nn.Linear(filter_dim * 2, filter_dim * 2)
        self.embed_fc2 = nn.Linear(filter_dim * 2, latent_dim_expand)

        self.steps = torch.nn.parameter.Parameter(torch.ones(args.num_steps), requires_grad=True)


    def embed_latent(self, im):
        x = self.embed_conv1(im)
        x = F.relu(x)
        x = self.embed_layer1(x)
        x = self.embed_layer2(x)
        x = x.mean(dim=2).mean(dim=2)
        x = x.view(x.size(0), -1)
        x = F.relu(self.embed_fc1(x))
        output = self.embed_fc2(x)

        return output

    def forward(self, x, latent):
        x = swish(self.conv1(x))
        x = self.avg_pool(x)
        x = self.layer_encode(x, latent)
        x = self.layer1(x, latent)
        x = self.layer2(x, latent)
        x = x.mean(dim=2).mean(dim=2)
        x = x.view(x.size(0), -1)


        x = swish(self.fc1(x))
        energy = self.energy_map(x)

        return energy


class DisentangleModel(nn.Module):
    def __init__(self):
        super(DisentangleModel, self).__init__()

        self.fc1 = nn.Linear(256, 256)
        self.fc2 = nn.Linear(256, 256)
        self.fc3 = nn.Linear(256, 6)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)

        return x


class PMM(nn.Module):
    def __init__(self, args):
        super(PMM, self).__init__()

        latent_dim = args.latent_dim * args.components
        self.latent_dim = latent_dim
        self.inner_dim = 1024

        self.fc1 = nn.Linear(self.latent_dim, self.inner_dim)
        self.fc2 = nn.Linear(self.inner_dim, self.inner_dim)
        self.fc3 = nn.Linear(self.inner_dim, self.inner_dim)
        self.fc4 = nn.Linear(self.inner_dim, 1)

    def forward(self, x):
        x = F.leaky_relu(self.fc1(x), 0.2)
        x = F.leaky_relu(self.fc2(x), 0.2)
        x = F.leaky_relu(self.fc3(x), 0.2)
        x = torch.sigmoid(self.fc4(x))

        return x


class LabelModel(nn.Module):
    def __init__(self, args):
        super(LabelModel, self).__init__()

        self.fc1 = nn.Linear(64, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, 5)

    def forward(self, x):
        x = F.leaky_relu(self.fc1(x), 0.2)
        x = F.leaky_relu(self.fc2(x), 0.2)
        x = F.leaky_relu(self.fc3(x), 0.2)

        return x

class BetaVAE_H(nn.Module):
    """Model proposed in original beta-VAE paper(Higgins et al, ICLR, 2017)."""

    def __init__(self, z_dim=10, nc=3):
        super(BetaVAE_H, self).__init__()
        self.z_dim = z_dim
        self.nc = nc
        self.encoder = nn.Sequential(
            nn.Conv2d(nc, 32, 4, 2, 1),          # B,  32, 32, 32
            nn.ReLU(True),
            nn.Conv2d(32, 32, 4, 2, 1),          # B,  32, 16, 16
            nn.ReLU(True),
            nn.Conv2d(32, 64, 4, 2, 1),          # B,  64,  8,  8
            nn.ReLU(True),
            nn.Conv2d(64, 64, 4, 2, 1),          # B,  64,  4,  4
            nn.ReLU(True),
            nn.Conv2d(64, 256, 4, 1),            # B, 256,  1,  1
            nn.ReLU(True),
            View((-1, 256*1*1)),                 # B, 256
            nn.Linear(256, z_dim*2),             # B, z_dim*2
        )
        self.decoder = nn.Sequential(
            nn.Linear(z_dim, 256),               # B, 256
            View((-1, 256, 1, 1)),               # B, 256,  1,  1
            nn.ReLU(True),
            nn.ConvTranspose2d(256, 64, 4),      # B,  64,  4,  4
            nn.ReLU(True),
            nn.ConvTranspose2d(64, 64, 4, 2, 1), # B,  64,  8,  8
            nn.ReLU(True),
            nn.ConvTranspose2d(64, 32, 4, 2, 1), # B,  32, 16, 16
            nn.ReLU(True),
            nn.ConvTranspose2d(32, 32, 4, 2, 1), # B,  32, 32, 32
            nn.ReLU(True),
            nn.ConvTranspose2d(32, nc, 4, 2, 1),  # B, nc, 64, 64
        )

        self.weight_init()

    def weight_init(self):
        for block in self._modules:
            for m in self._modules[block]:
                kaiming_init(m)

    def forward(self, x, return_z=False):
        distributions = self._encode(x)
        mu = distributions[:, :self.z_dim]
        logvar = distributions[:, self.z_dim:]
        z = reparametrize(mu, logvar)
        x_recon = self._decode(z)

        if return_z:
            return x_recon, mu, logvar, z
        else:
            return x_recon, mu, logvar

    def _encode(self, x):
        return self.encoder(x)

    def _decode(self, z):
        return self.decoder(z)

    def reconstruction_loss(self, x, x_recon, distribution):
        batch_size = x.size(0)
        assert batch_size != 0

        if distribution == 'bernoulli':
            recon_loss = F.binary_cross_entropy_with_logits(
                x_recon, x, size_average=False).div(batch_size)
        elif distribution == 'gaussian':
            x_recon = F.sigmoid(x_recon)
            recon_loss = F.mse_loss(x_recon, x, size_average=False).div(batch_size)
        else:
            recon_loss = None

        return recon_loss

    def compute_cross_ent_normal(self, mu, logvar):
        return 0.5 * (mu**2 + torch.exp(logvar)) + np.log(np.sqrt(2 * np.pi))

    def compute_ent_normal(self, logvar):
        return 0.5 * (logvar + np.log(2 * np.pi * np.e))

'''
if __name__ == "__main__":
    args = EasyDict()
    args.filter_dim = 64
    args.latent_dim = 64
    args.im_size = 256

    model = LatentEBM(args).cuda()
    x = torch.zeros(1, 3, 256, 256).cuda()
    latent = torch.zeros(1, 64).cuda()
    model(x, latent)
  '''
# Out:
# '\nif __name__ == "__main__":\n    args = EasyDict()\n    args.filter_dim = 64\n    args.latent_dim = 64\n    args.im_size = 256\n\n    model = LatentEBM(args).cuda()\n    x = torch.zeros(1, 3, 256, 256).cuda()\n    latent = torch.zeros(1, 64).cuda()\n    model(x, latent)\n  '

# %%
# !tar -xvzf /content/images_clevr.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# images_clevr/CLEVR_new_006654.png
# images_clevr/CLEVR_new_007014.png
# images_clevr/CLEVR_new_004101.png
# images_clevr/CLEVR_new_008166.png
# images_clevr/CLEVR_new_009726.png
# images_clevr/CLEVR_new_005741.png
# images_clevr/CLEVR_new_009081.png
# images_clevr/CLEVR_new_007807.png
# images_clevr/CLEVR_new_007475.png
# images_clevr/CLEVR_new_006235.png
# images_clevr/CLEVR_new_003919.png
# images_clevr/CLEVR_new_006592.png
# images_clevr/CLEVR_new_009347.png
# images_clevr/CLEVR_new_005320.png
# images_clevr/CLEVR_new_009892.png
# images_clevr/CLEVR_new_005487.png
# images_clevr/CLEVR_new_004560.png
# images_clevr/CLEVR_new_004912.png
# images_clevr/CLEVR_new_008975.png
# images_clevr/CLEVR_new_008507.png
# images_clevr/CLEVR_new_001599.png
# images_clevr/CLEVR_new_005681.png
# images_clevr/CLEVR_new_009141.png
# images_clevr/CLEVR_new_005126.png
# images_clevr/CLEVR_new_000678.png
# images_clevr/CLEVR_new_001038.png
# images_clevr/CLEVR_new_004766.png
# images_clevr/CLEVR_new_008701.png
# images_clevr/CLEVR_new_007673.png
# images_clevr/CLEVR_new_006794.png
# images_clevr/CLEVR_new_006033.png
# images_clevr/CLEVR_new_004307.png
# images_clevr/CLEVR_new_001459.png
# images_clevr/CLEVR_new_008360.png
# images_clevr/CLEVR_new_009287.png
# images_clevr/CLEVR_new_009520.png
# images_clevr/CLEVR_new_009952.png
# images_clevr/CLEVR_new_000219.png
# images_clevr/CLEVR_new_005935.png
# images_clevr/CLEVR_new_005547.png
# images_clevr/CLEVR_new_006452.png
# images_clevr/CLEVR_new_006820.png
# images_clevr/CLEVR_new_007212.png
# images_clevr/CLEVR_new_007564.png
# images_clevr/CLEVR_new_007916.png
# images_clevr/CLEVR_new_003808.png
# images_clevr/CLEVR_new_006324.png
# images_clevr/CLEVR_new_006483.png
# images_clevr/CLEVR_new_005231.png
# images_clevr/CLEVR_new_009256.png
# images_clevr/CLEVR_new_005596.png
# images_clevr/CLEVR_new_009983.png
# images_clevr/CLEVR_new_008416.png
# images_clevr/CLEVR_new_008864.png
# images_clevr/CLEVR_new_004803.png
# images_clevr/CLEVR_new_004471.png
# images_clevr/CLEVR_new_001488.png
# images_clevr/CLEVR_new_006745.png
# images_clevr/CLEVR_new_007105.png
# images_clevr/CLEVR_new_008077.png
# images_clevr/CLEVR_new_004010.png
# images_clevr/CLEVR_new_005650.png
# images_clevr/CLEVR_new_009637.png
# images_clevr/CLEVR_new_009190.png
# images_clevr/CLEVR_new_005369.png
# images_clevr/CLEVR_new_000845.png
# images_clevr/CLEVR_new_000437.png
# images_clevr/CLEVR_new_000390.png
# images_clevr/CLEVR_new_001277.png
# images_clevr/CLEVR_new_004529.png
# images_clevr/CLEVR_new_002362.png
# images_clevr/CLEVR_new_010165.png
# images_clevr/CLEVR_new_003522.png
# images_clevr/CLEVR_new_003950.png
# images_clevr/CLEVR_new_011082.png
# images_clevr/CLEVR_new_003285.png
# images_clevr/CLEVR_new_004148.png
# images_clevr/CLEVR_new_001616.png
# images_clevr/CLEVR_new_008688.png
# images_clevr/CLEVR_new_000056.png
# images_clevr/CLEVR_new_005708.png
# images_clevr/CLEVR_new_003143.png
# images_clevr/CLEVR_new_011344.png
# images_clevr/CLEVR_new_002703.png
# images_clevr/CLEVR_new_010976.png
# images_clevr/CLEVR_new_010504.png
# images_clevr/CLEVR_new_010272.png
# images_clevr/CLEVR_new_002075.png
# images_clevr/CLEVR_new_003192.png
# images_clevr/CLEVR_new_011395.png
# images_clevr/CLEVR_new_003635.png
# images_clevr/CLEVR_new_000087.png
# images_clevr/CLEVR_new_009019.png
# images_clevr/CLEVR_new_000720.png
# images_clevr/CLEVR_new_004199.png
# images_clevr/CLEVR_new_001160.png
# images_clevr/CLEVR_new_008659.png
# images_clevr/CLEVR_new_011053.png
# images_clevr/CLEVR_new_003981.png
# images_clevr/CLEVR_new_006978.png
# images_clevr/CLEVR_new_003254.png
# images_clevr/CLEVR_new_010613.png
# images_clevr/CLEVR_new_002414.png
# images_clevr/CLEVR_new_002866.png
# images_clevr/CLEVR_new_001973.png
# images_clevr/CLEVR_new_001501.png
# images_clevr/CLEVR_new_008238.png
# images_clevr/CLEVR_new_000894.png
# images_clevr/CLEVR_new_009478.png
# images_clevr/CLEVR_new_000341.png
# images_clevr/CLEVR_new_002151.png
# images_clevr/CLEVR_new_010883.png
# images_clevr/CLEVR_new_010356.png
# images_clevr/CLEVR_new_003711.png
# images_clevr/CLEVR_new_000604.png
# images_clevr/CLEVR_new_001044.png
# images_clevr/CLEVR_new_003370.png
# images_clevr/CLEVR_new_011177.png
# images_clevr/CLEVR_new_006389.png
# images_clevr/CLEVR_new_002942.png
# images_clevr/CLEVR_new_002530.png
# images_clevr/CLEVR_new_010090.png
# images_clevr/CLEVR_new_002297.png
# images_clevr/CLEVR_new_010737.png
# images_clevr/CLEVR_new_001425.png
# images_clevr/CLEVR_new_001857.png
# images_clevr/CLEVR_new_001382.png
# images_clevr/CLEVR_new_000265.png
# images_clevr/CLEVR_new_005949.png
# images_clevr/CLEVR_new_005998.png
# images_clevr/CLEVR_new_000513.png
# images_clevr/CLEVR_new_000961.png
# images_clevr/CLEVR_new_001886.png
# images_clevr/CLEVR_new_008818.png
# images_clevr/CLEVR_new_001353.png
# images_clevr/CLEVR_new_010041.png
# images_clevr/CLEVR_new_002993.png
# images_clevr/CLEVR_new_007518.png
# images_clevr/CLEVR_new_002246.png
# images_clevr/CLEVR_new_003874.png
# images_clevr/CLEVR_new_003406.png
# images_clevr/CLEVR_new_006358.png
# images_clevr/CLEVR_new_001095.png
# images_clevr/CLEVR_new_001732.png
# images_clevr/CLEVR_new_000172.png
# images_clevr/CLEVR_new_011260.png
# images_clevr/CLEVR_new_006739.png
# images_clevr/CLEVR_new_003067.png
# images_clevr/CLEVR_new_010420.png
# images_clevr/CLEVR_new_010852.png
# images_clevr/CLEVR_new_002180.png
# images_clevr/CLEVR_new_010387.png
# images_clevr/CLEVR_new_002627.png
# images_clevr/CLEVR_new_007179.png
# images_clevr/CLEVR_new_010119.png
# images_clevr/CLEVR_new_007832.png
# images_clevr/CLEVR_new_007440.png
# images_clevr/CLEVR_new_006200.png
# images_clevr/CLEVR_new_005315.png
# images_clevr/CLEVR_new_000839.png
# images_clevr/CLEVR_new_009372.png
# images_clevr/CLEVR_new_008295.png
# images_clevr/CLEVR_new_008940.png
# images_clevr/CLEVR_new_008532.png
# images_clevr/CLEVR_new_004555.png
# images_clevr/CLEVR_new_004927.png
# images_clevr/CLEVR_new_003698.png
# images_clevr/CLEVR_new_011338.png
# images_clevr/CLEVR_new_006661.png
# images_clevr/CLEVR_new_010578.png
# images_clevr/CLEVR_new_007786.png
# images_clevr/CLEVR_new_007021.png
# images_clevr/CLEVR_new_004693.png
# images_clevr/CLEVR_new_008153.png
# images_clevr/CLEVR_new_004134.png
# images_clevr/CLEVR_new_005774.png
# images_clevr/CLEVR_new_009713.png
# images_clevr/CLEVR_new_009065.png
# images_clevr/CLEVR_new_005002.png
# images_clevr/CLEVR_new_004642.png
# images_clevr/CLEVR_new_008625.png
# images_clevr/CLEVR_new_008182.png
# images_clevr/CLEVR_new_007757.png
# images_clevr/CLEVR_new_002009.png
# images_clevr/CLEVR_new_003649.png
# images_clevr/CLEVR_new_006117.png
# images_clevr/CLEVR_new_004223.png
# images_clevr/CLEVR_new_008244.png
# images_clevr/CLEVR_new_004584.png
# images_clevr/CLEVR_new_008991.png
# images_clevr/CLEVR_new_009876.png
# images_clevr/CLEVR_new_009404.png
# images_clevr/CLEVR_new_005463.png
# images_clevr/CLEVR_new_005811.png
# images_clevr/CLEVR_new_006904.png
# images_clevr/CLEVR_new_006576.png
# images_clevr/CLEVR_new_003228.png
# images_clevr/CLEVR_new_002468.png
# images_clevr/CLEVR_new_007336.png
# images_clevr/CLEVR_new_007491.png
# images_clevr/CLEVR_new_003716.png
# images_clevr/CLEVR_new_006048.png
# images_clevr/CLEVR_new_010351.png
# images_clevr/CLEVR_new_007608.png
# images_clevr/CLEVR_new_002156.png
# images_clevr/CLEVR_new_010884.png
# images_clevr/CLEVR_new_001043.png
# images_clevr/CLEVR_new_000603.png
# images_clevr/CLEVR_new_002290.png
# images_clevr/CLEVR_new_010730.png
# images_clevr/CLEVR_new_002537.png
# images_clevr/CLEVR_new_002945.png
# images_clevr/CLEVR_new_007269.png
# images_clevr/CLEVR_new_010097.png
# images_clevr/CLEVR_new_011170.png
# images_clevr/CLEVR_new_006429.png
# images_clevr/CLEVR_new_003377.png
# images_clevr/CLEVR_new_009929.png
# images_clevr/CLEVR_new_000262.png
# images_clevr/CLEVR_new_001385.png
# images_clevr/CLEVR_new_001850.png
# images_clevr/CLEVR_new_001422.png
# images_clevr/CLEVR_new_001354.png
# images_clevr/CLEVR_new_004878.png
# images_clevr/CLEVR_new_001881.png
# images_clevr/CLEVR_new_000966.png
# images_clevr/CLEVR_new_000514.png
# images_clevr/CLEVR_new_003401.png
# images_clevr/CLEVR_new_003873.png
# images_clevr/CLEVR_new_002241.png
# images_clevr/CLEVR_new_010046.png
# images_clevr/CLEVR_new_002994.png
# images_clevr/CLEVR_new_000175.png
# images_clevr/CLEVR_new_001735.png
# images_clevr/CLEVR_new_001092.png
# images_clevr/CLEVR_new_010380.png
# images_clevr/CLEVR_new_002620.png
# images_clevr/CLEVR_new_010855.png
# images_clevr/CLEVR_new_010427.png
# images_clevr/CLEVR_new_002187.png
# images_clevr/CLEVR_new_003060.png
# images_clevr/CLEVR_new_006099.png
# images_clevr/CLEVR_new_011267.png
# images_clevr/CLEVR_new_003559.png
# images_clevr/CLEVR_new_006207.png
# images_clevr/CLEVR_new_007447.png
# images_clevr/CLEVR_new_007835.png
# images_clevr/CLEVR_new_002319.png
# images_clevr/CLEVR_new_008535.png
# images_clevr/CLEVR_new_008947.png
# images_clevr/CLEVR_new_004920.png
# images_clevr/CLEVR_new_004552.png
# images_clevr/CLEVR_new_008292.png
# images_clevr/CLEVR_new_005312.png
# images_clevr/CLEVR_new_009375.png
# images_clevr/CLEVR_new_002778.png
# images_clevr/CLEVR_new_007026.png
# images_clevr/CLEVR_new_007781.png
# images_clevr/CLEVR_new_006666.png
# images_clevr/CLEVR_new_003138.png
# images_clevr/CLEVR_new_005773.png
# images_clevr/CLEVR_new_009714.png
# images_clevr/CLEVR_new_008154.png
# images_clevr/CLEVR_new_004133.png
# images_clevr/CLEVR_new_004694.png
# images_clevr/CLEVR_new_008185.png
# images_clevr/CLEVR_new_004645.png
# images_clevr/CLEVR_new_008622.png
# images_clevr/CLEVR_new_009062.png
# images_clevr/CLEVR_new_005005.png
# images_clevr/CLEVR_new_006110.png
# images_clevr/CLEVR_new_010209.png
# images_clevr/CLEVR_new_007750.png
# images_clevr/CLEVR_new_009403.png
# images_clevr/CLEVR_new_009871.png
# images_clevr/CLEVR_new_005816.png
# images_clevr/CLEVR_new_005464.png
# images_clevr/CLEVR_new_004583.png
# images_clevr/CLEVR_new_008996.png
# images_clevr/CLEVR_new_004224.png
# images_clevr/CLEVR_new_001908.png
# images_clevr/CLEVR_new_008243.png
# images_clevr/CLEVR_new_007496.png
# images_clevr/CLEVR_new_010668.png
# images_clevr/CLEVR_new_007331.png
# images_clevr/CLEVR_new_011028.png
# images_clevr/CLEVR_new_003588.png
# images_clevr/CLEVR_new_006571.png
# images_clevr/CLEVR_new_006903.png
# images_clevr/CLEVR_new_004761.png
# images_clevr/CLEVR_new_008706.png
# images_clevr/CLEVR_new_001798.png
# images_clevr/CLEVR_new_009146.png
# images_clevr/CLEVR_new_005121.png
# images_clevr/CLEVR_new_005686.png
# images_clevr/CLEVR_new_006034.png
# images_clevr/CLEVR_new_006793.png
# images_clevr/CLEVR_new_007674.png
# images_clevr/CLEVR_new_009955.png
# images_clevr/CLEVR_new_009527.png
# images_clevr/CLEVR_new_005540.png
# images_clevr/CLEVR_new_005932.png
# images_clevr/CLEVR_new_009280.png
# images_clevr/CLEVR_new_004300.png
# images_clevr/CLEVR_new_008367.png
# images_clevr/CLEVR_new_002939.png
# images_clevr/CLEVR_new_007215.png
# images_clevr/CLEVR_new_006827.png
# images_clevr/CLEVR_new_006455.png
# images_clevr/CLEVR_new_006484.png
# images_clevr/CLEVR_new_006323.png
# images_clevr/CLEVR_new_007911.png
# images_clevr/CLEVR_new_007563.png
# images_clevr/CLEVR_new_008863.png
# images_clevr/CLEVR_new_008411.png
# images_clevr/CLEVR_new_001328.png
# images_clevr/CLEVR_new_004476.png
# images_clevr/CLEVR_new_004804.png
# images_clevr/CLEVR_new_005591.png
# images_clevr/CLEVR_new_009984.png
# images_clevr/CLEVR_new_005236.png
# images_clevr/CLEVR_new_000568.png
# images_clevr/CLEVR_new_009251.png
# images_clevr/CLEVR_new_010829.png
# images_clevr/CLEVR_new_007102.png
# images_clevr/CLEVR_new_006742.png
# images_clevr/CLEVR_new_009197.png
# images_clevr/CLEVR_new_000109.png
# images_clevr/CLEVR_new_005657.png
# images_clevr/CLEVR_new_009630.png
# images_clevr/CLEVR_new_008070.png
# images_clevr/CLEVR_new_004017.png
# images_clevr/CLEVR_new_001749.png
# images_clevr/CLEVR_new_004289.png
# images_clevr/CLEVR_new_008549.png
# images_clevr/CLEVR_new_001270.png
# images_clevr/CLEVR_new_000397.png
# images_clevr/CLEVR_new_000430.png
# images_clevr/CLEVR_new_000842.png
# images_clevr/CLEVR_new_009309.png
# images_clevr/CLEVR_new_003282.png
# images_clevr/CLEVR_new_003957.png
# images_clevr/CLEVR_new_003525.png
# images_clevr/CLEVR_new_011085.png
# images_clevr/CLEVR_new_010162.png
# images_clevr/CLEVR_new_007849.png
# images_clevr/CLEVR_new_002365.png
# images_clevr/CLEVR_new_000051.png
# images_clevr/CLEVR_new_009768.png
# images_clevr/CLEVR_new_008128.png
# images_clevr/CLEVR_new_001611.png
# images_clevr/CLEVR_new_010503.png
# images_clevr/CLEVR_new_010971.png
# images_clevr/CLEVR_new_002704.png
# images_clevr/CLEVR_new_011343.png
# images_clevr/CLEVR_new_003144.png
# images_clevr/CLEVR_new_011392.png
# images_clevr/CLEVR_new_003632.png
# images_clevr/CLEVR_new_003195.png
# images_clevr/CLEVR_new_002072.png
# images_clevr/CLEVR_new_010275.png
# images_clevr/CLEVR_new_001167.png
# images_clevr/CLEVR_new_004639.png
# images_clevr/CLEVR_new_005079.png
# images_clevr/CLEVR_new_000727.png
# images_clevr/CLEVR_new_000080.png
# images_clevr/CLEVR_new_002861.png
# images_clevr/CLEVR_new_002413.png
# images_clevr/CLEVR_new_007898.png
# images_clevr/CLEVR_new_010614.png
# images_clevr/CLEVR_new_003253.png
# images_clevr/CLEVR_new_011054.png
# images_clevr/CLEVR_new_003986.png
# images_clevr/CLEVR_new_000346.png
# images_clevr/CLEVR_new_005418.png
# images_clevr/CLEVR_new_000893.png
# images_clevr/CLEVR_new_004258.png
# images_clevr/CLEVR_new_001506.png
# images_clevr/CLEVR_new_001974.png
# images_clevr/CLEVR_new_008598.png
# images_clevr/CLEVR_new_009693.png
# images_clevr/CLEVR_new_005153.png
# images_clevr/CLEVR_new_009134.png
# images_clevr/CLEVR_new_008774.png
# images_clevr/CLEVR_new_004713.png
# images_clevr/CLEVR_new_007606.png
# images_clevr/CLEVR_new_002158.png
# images_clevr/CLEVR_new_003718.png
# images_clevr/CLEVR_new_006046.png
# images_clevr/CLEVR_new_008315.png
# images_clevr/CLEVR_new_004372.png
# images_clevr/CLEVR_new_005295.png
# images_clevr/CLEVR_new_005532.png
# images_clevr/CLEVR_new_005940.png
# images_clevr/CLEVR_new_009927.png
# images_clevr/CLEVR_new_009555.png
# images_clevr/CLEVR_new_006380.png
# images_clevr/CLEVR_new_006855.png
# images_clevr/CLEVR_new_006427.png
# images_clevr/CLEVR_new_003379.png
# images_clevr/CLEVR_new_010099.png
# images_clevr/CLEVR_new_002539.png
# images_clevr/CLEVR_new_007267.png
# images_clevr/CLEVR_new_007963.png
# images_clevr/CLEVR_new_007511.png
# images_clevr/CLEVR_new_010048.png
# images_clevr/CLEVR_new_006351.png
# images_clevr/CLEVR_new_006884.png
# images_clevr/CLEVR_new_009223.png
# images_clevr/CLEVR_new_005244.png
# images_clevr/CLEVR_new_000968.png
# images_clevr/CLEVR_new_009584.png
# images_clevr/CLEVR_new_005991.png
# images_clevr/CLEVR_new_004404.png
# images_clevr/CLEVR_new_004876.png
# images_clevr/CLEVR_new_008811.png
# images_clevr/CLEVR_new_008463.png
# images_clevr/CLEVR_new_006730.png
# images_clevr/CLEVR_new_011269.png
# images_clevr/CLEVR_new_006097.png
# images_clevr/CLEVR_new_007170.png
# images_clevr/CLEVR_new_002189.png
# images_clevr/CLEVR_new_010429.png
# images_clevr/CLEVR_new_004065.png
# images_clevr/CLEVR_new_008002.png
# images_clevr/CLEVR_new_009642.png
# images_clevr/CLEVR_new_005625.png
# images_clevr/CLEVR_new_005182.png
# images_clevr/CLEVR_new_000442.png
# images_clevr/CLEVR_new_000830.png
# images_clevr/CLEVR_new_001202.png
# images_clevr/CLEVR_new_008949.png
# images_clevr/CLEVR_new_007449.png
# images_clevr/CLEVR_new_002317.png
# images_clevr/CLEVR_new_010110.png
# images_clevr/CLEVR_new_003925.png
# images_clevr/CLEVR_new_003557.png
# images_clevr/CLEVR_new_006209.png
# images_clevr/CLEVR_new_001663.png
# images_clevr/CLEVR_new_000023.png
# images_clevr/CLEVR_new_000784.png
# images_clevr/CLEVR_new_006668.png
# images_clevr/CLEVR_new_003136.png
# images_clevr/CLEVR_new_011331.png
# images_clevr/CLEVR_new_003691.png
# images_clevr/CLEVR_new_002776.png
# images_clevr/CLEVR_new_007028.png
# images_clevr/CLEVR_new_010571.png
# images_clevr/CLEVR_new_010903.png
# images_clevr/CLEVR_new_010207.png
# images_clevr/CLEVR_new_002000.png
# images_clevr/CLEVR_new_003640.png
# images_clevr/CLEVR_new_000755.png
# images_clevr/CLEVR_new_001115.png
# images_clevr/CLEVR_new_003586.png
# images_clevr/CLEVR_new_011026.png
# images_clevr/CLEVR_new_003221.png
# images_clevr/CLEVR_new_010666.png
# images_clevr/CLEVR_new_007498.png
# images_clevr/CLEVR_new_002813.png
# images_clevr/CLEVR_new_002461.png
# images_clevr/CLEVR_new_008998.png
# images_clevr/CLEVR_new_001574.png
# images_clevr/CLEVR_new_001906.png
# images_clevr/CLEVR_new_000493.png
# images_clevr/CLEVR_new_000334.png
# images_clevr/CLEVR_new_005818.png
# images_clevr/CLEVR_new_010484.png
# images_clevr/CLEVR_new_002124.png
# images_clevr/CLEVR_new_010323.png
# images_clevr/CLEVR_new_002683.png
# images_clevr/CLEVR_new_003764.png
# images_clevr/CLEVR_new_000671.png
# images_clevr/CLEVR_new_009148.png
# images_clevr/CLEVR_new_005688.png
# images_clevr/CLEVR_new_008708.png
# images_clevr/CLEVR_new_001031.png
# images_clevr/CLEVR_new_001796.png
# images_clevr/CLEVR_new_006829.png
# images_clevr/CLEVR_new_003305.png
# images_clevr/CLEVR_new_011102.png
# images_clevr/CLEVR_new_002545.png
# images_clevr/CLEVR_new_002937.png
# images_clevr/CLEVR_new_010742.png
# images_clevr/CLEVR_new_008369.png
# images_clevr/CLEVR_new_001822.png
# images_clevr/CLEVR_new_001450.png
# images_clevr/CLEVR_new_000210.png
# images_clevr/CLEVR_new_009529.png
# images_clevr/CLEVR_new_005238.png
# images_clevr/CLEVR_new_000914.png
# images_clevr/CLEVR_new_000566.png
# images_clevr/CLEVR_new_001481.png
# images_clevr/CLEVR_new_001326.png
# images_clevr/CLEVR_new_004478.png
# images_clevr/CLEVR_new_002594.png
# images_clevr/CLEVR_new_010034.png
# images_clevr/CLEVR_new_002233.png
# images_clevr/CLEVR_new_010793.png
# images_clevr/CLEVR_new_003473.png
# images_clevr/CLEVR_new_003801.png
# images_clevr/CLEVR_new_004019.png
# images_clevr/CLEVR_new_001747.png
# images_clevr/CLEVR_new_009199.png
# images_clevr/CLEVR_new_000107.png
# images_clevr/CLEVR_new_005659.png
# images_clevr/CLEVR_new_011215.png
# images_clevr/CLEVR_new_003012.png
# images_clevr/CLEVR_new_010827.png
# images_clevr/CLEVR_new_010455.png
# images_clevr/CLEVR_new_002652.png
# images_clevr/CLEVR_new_007392.png
# images_clevr/CLEVR_new_007435.png
# images_clevr/CLEVR_new_007847.png
# images_clevr/CLEVR_new_003959.png
# images_clevr/CLEVR_new_006275.png
# images_clevr/CLEVR_new_000399.png
# images_clevr/CLEVR_new_009307.png
# images_clevr/CLEVR_new_005360.png
# images_clevr/CLEVR_new_004287.png
# images_clevr/CLEVR_new_004952.png
# images_clevr/CLEVR_new_004520.png
# images_clevr/CLEVR_new_008547.png
# images_clevr/CLEVR_new_008935.png
# images_clevr/CLEVR_new_006614.png
# images_clevr/CLEVR_new_007054.png
# images_clevr/CLEVR_new_008681.png
# images_clevr/CLEVR_new_004141.png
# images_clevr/CLEVR_new_008126.png
# images_clevr/CLEVR_new_009766.png
# images_clevr/CLEVR_new_005701.png
# images_clevr/CLEVR_new_005077.png
# images_clevr/CLEVR_new_000729.png
# images_clevr/CLEVR_new_009010.png
# images_clevr/CLEVR_new_008650.png
# images_clevr/CLEVR_new_001169.png
# images_clevr/CLEVR_new_004637.png
# images_clevr/CLEVR_new_004190.png
# images_clevr/CLEVR_new_007722.png
# images_clevr/CLEVR_new_007085.png
# images_clevr/CLEVR_new_006162.png
# images_clevr/CLEVR_new_008231.png
# images_clevr/CLEVR_new_004256.png
# images_clevr/CLEVR_new_001508.png
# images_clevr/CLEVR_new_008596.png
# images_clevr/CLEVR_new_004983.png
# images_clevr/CLEVR_new_000348.png
# images_clevr/CLEVR_new_005864.png
# images_clevr/CLEVR_new_005416.png
# images_clevr/CLEVR_new_009471.png
# images_clevr/CLEVR_new_009803.png
# images_clevr/CLEVR_new_006503.png
# images_clevr/CLEVR_new_006971.png
# images_clevr/CLEVR_new_003988.png
# images_clevr/CLEVR_new_007343.png
# images_clevr/CLEVR_new_007896.png
# images_clevr/CLEVR_new_003763.png
# images_clevr/CLEVR_new_010324.png
# images_clevr/CLEVR_new_002684.png
# images_clevr/CLEVR_new_010483.png
# images_clevr/CLEVR_new_002123.png
# images_clevr/CLEVR_new_001791.png
# images_clevr/CLEVR_new_001036.png
# images_clevr/CLEVR_new_004768.png
# images_clevr/CLEVR_new_005128.png
# images_clevr/CLEVR_new_000676.png
# images_clevr/CLEVR_new_010745.png
# images_clevr/CLEVR_new_002930.png
# images_clevr/CLEVR_new_002542.png
# images_clevr/CLEVR_new_011105.png
# images_clevr/CLEVR_new_003302.png
# images_clevr/CLEVR_new_009289.png
# images_clevr/CLEVR_new_000217.png
# images_clevr/CLEVR_new_005549.png
# images_clevr/CLEVR_new_004309.png
# images_clevr/CLEVR_new_001457.png
# images_clevr/CLEVR_new_001825.png
# images_clevr/CLEVR_new_001321.png
# images_clevr/CLEVR_new_008418.png
# images_clevr/CLEVR_new_001486.png
# images_clevr/CLEVR_new_009258.png
# images_clevr/CLEVR_new_000561.png
# images_clevr/CLEVR_new_000913.png
# images_clevr/CLEVR_new_005598.png
# images_clevr/CLEVR_new_003806.png
# images_clevr/CLEVR_new_003474.png
# images_clevr/CLEVR_new_007918.png
# images_clevr/CLEVR_new_002234.png
# images_clevr/CLEVR_new_010794.png
# images_clevr/CLEVR_new_002593.png
# images_clevr/CLEVR_new_010033.png
# images_clevr/CLEVR_new_009639.png
# images_clevr/CLEVR_new_000100.png
# images_clevr/CLEVR_new_001740.png
# images_clevr/CLEVR_new_008079.png
# images_clevr/CLEVR_new_002655.png
# images_clevr/CLEVR_new_010452.png
# images_clevr/CLEVR_new_010820.png
# images_clevr/CLEVR_new_003015.png
# images_clevr/CLEVR_new_011212.png
# images_clevr/CLEVR_new_006272.png
# images_clevr/CLEVR_new_007840.png
# images_clevr/CLEVR_new_007432.png
# images_clevr/CLEVR_new_007395.png
# images_clevr/CLEVR_new_001279.png
# images_clevr/CLEVR_new_004527.png
# images_clevr/CLEVR_new_004955.png
# images_clevr/CLEVR_new_008932.png
# images_clevr/CLEVR_new_008540.png
# images_clevr/CLEVR_new_004280.png
# images_clevr/CLEVR_new_009300.png
# images_clevr/CLEVR_new_005367.png
# images_clevr/CLEVR_new_000439.png
# images_clevr/CLEVR_new_007053.png
# images_clevr/CLEVR_new_010978.png
# images_clevr/CLEVR_new_006613.png
# images_clevr/CLEVR_new_009761.png
# images_clevr/CLEVR_new_000058.png
# images_clevr/CLEVR_new_005706.png
# images_clevr/CLEVR_new_004146.png
# images_clevr/CLEVR_new_001618.png
# images_clevr/CLEVR_new_008121.png
# images_clevr/CLEVR_new_008686.png
# images_clevr/CLEVR_new_004197.png
# images_clevr/CLEVR_new_008657.png
# images_clevr/CLEVR_new_004630.png
# images_clevr/CLEVR_new_000089.png
# images_clevr/CLEVR_new_005070.png
# images_clevr/CLEVR_new_009017.png
# images_clevr/CLEVR_new_006165.png
# images_clevr/CLEVR_new_007082.png
# images_clevr/CLEVR_new_007725.png
# images_clevr/CLEVR_new_005411.png
# images_clevr/CLEVR_new_005863.png
# images_clevr/CLEVR_new_009804.png
# images_clevr/CLEVR_new_009476.png
# images_clevr/CLEVR_new_008591.png
# images_clevr/CLEVR_new_004984.png
# images_clevr/CLEVR_new_008236.png
# images_clevr/CLEVR_new_004251.png
# images_clevr/CLEVR_new_007891.png
# images_clevr/CLEVR_new_002868.png
# images_clevr/CLEVR_new_007344.png
# images_clevr/CLEVR_new_006976.png
# images_clevr/CLEVR_new_006504.png
# images_clevr/CLEVR_new_008773.png
# images_clevr/CLEVR_new_004714.png
# images_clevr/CLEVR_new_005154.png
# images_clevr/CLEVR_new_009133.png
# images_clevr/CLEVR_new_009694.png
# images_clevr/CLEVR_new_006041.png
# images_clevr/CLEVR_new_007601.png
# images_clevr/CLEVR_new_010358.png
# images_clevr/CLEVR_new_005947.png
# images_clevr/CLEVR_new_005535.png
# images_clevr/CLEVR_new_009552.png
# images_clevr/CLEVR_new_009920.png
# images_clevr/CLEVR_new_005292.png
# images_clevr/CLEVR_new_008312.png
# images_clevr/CLEVR_new_004375.png
# images_clevr/CLEVR_new_001859.png
# images_clevr/CLEVR_new_007260.png
# images_clevr/CLEVR_new_010739.png
# images_clevr/CLEVR_new_002299.png
# images_clevr/CLEVR_new_006420.png
# images_clevr/CLEVR_new_006852.png
# images_clevr/CLEVR_new_006387.png
# images_clevr/CLEVR_new_011179.png
# images_clevr/CLEVR_new_006883.png
# images_clevr/CLEVR_new_003408.png
# images_clevr/CLEVR_new_006356.png
# images_clevr/CLEVR_new_007516.png
# images_clevr/CLEVR_new_007964.png
# images_clevr/CLEVR_new_002248.png
# images_clevr/CLEVR_new_001888.png
# images_clevr/CLEVR_new_004871.png
# images_clevr/CLEVR_new_004403.png
# images_clevr/CLEVR_new_008464.png
# images_clevr/CLEVR_new_008816.png
# images_clevr/CLEVR_new_009583.png
# images_clevr/CLEVR_new_005996.png
# images_clevr/CLEVR_new_009224.png
# images_clevr/CLEVR_new_005243.png
# images_clevr/CLEVR_new_002629.png
# images_clevr/CLEVR_new_007177.png
# images_clevr/CLEVR_new_010389.png
# images_clevr/CLEVR_new_006090.png
# images_clevr/CLEVR_new_006737.png
# images_clevr/CLEVR_new_003069.png
# images_clevr/CLEVR_new_005185.png
# images_clevr/CLEVR_new_009645.png
# images_clevr/CLEVR_new_005622.png
# images_clevr/CLEVR_new_004062.png
# images_clevr/CLEVR_new_008005.png
# images_clevr/CLEVR_new_001205.png
# images_clevr/CLEVR_new_004929.png
# images_clevr/CLEVR_new_000837.png
# images_clevr/CLEVR_new_000445.png
# images_clevr/CLEVR_new_003550.png
# images_clevr/CLEVR_new_003922.png
# images_clevr/CLEVR_new_010117.png
# images_clevr/CLEVR_new_002310.png
# images_clevr/CLEVR_new_000783.png
# images_clevr/CLEVR_new_000024.png
# images_clevr/CLEVR_new_001664.png
# images_clevr/CLEVR_new_007788.png
# images_clevr/CLEVR_new_010904.png
# images_clevr/CLEVR_new_010576.png
# images_clevr/CLEVR_new_002771.png
# images_clevr/CLEVR_new_011336.png
# images_clevr/CLEVR_new_003696.png
# images_clevr/CLEVR_new_003131.png
# images_clevr/CLEVR_new_003647.png
# images_clevr/CLEVR_new_006119.png
# images_clevr/CLEVR_new_007759.png
# images_clevr/CLEVR_new_002007.png
# images_clevr/CLEVR_new_010200.png
# images_clevr/CLEVR_new_001112.png
# images_clevr/CLEVR_new_000752.png
# images_clevr/CLEVR_new_002466.png
# images_clevr/CLEVR_new_002814.png
# images_clevr/CLEVR_new_007338.png
# images_clevr/CLEVR_new_010661.png
# images_clevr/CLEVR_new_006578.png
# images_clevr/CLEVR_new_003226.png
# images_clevr/CLEVR_new_003581.png
# images_clevr/CLEVR_new_011021.png
# images_clevr/CLEVR_new_000333.png
# images_clevr/CLEVR_new_009878.png
# images_clevr/CLEVR_new_000494.png
# images_clevr/CLEVR_new_001901.png
# images_clevr/CLEVR_new_001573.png
# images_clevr/CLEVR_new_006174.png
# images_clevr/CLEVR_new_007734.png
# images_clevr/CLEVR_new_007093.png
# images_clevr/CLEVR_new_008646.png
# images_clevr/CLEVR_new_004621.png
# images_clevr/CLEVR_new_004186.png
# images_clevr/CLEVR_new_005061.png
# images_clevr/CLEVR_new_009006.png
# images_clevr/CLEVR_new_000098.png
# images_clevr/CLEVR_new_002879.png
# images_clevr/CLEVR_new_007355.png
# images_clevr/CLEVR_new_007880.png
# images_clevr/CLEVR_new_006515.png
# images_clevr/CLEVR_new_006967.png
# images_clevr/CLEVR_new_005872.png
# images_clevr/CLEVR_new_005400.png
# images_clevr/CLEVR_new_009467.png
# images_clevr/CLEVR_new_009815.png
# images_clevr/CLEVR_new_008227.png
# images_clevr/CLEVR_new_004240.png
# images_clevr/CLEVR_new_008580.png
# images_clevr/CLEVR_new_004995.png
# images_clevr/CLEVR_new_004291.png
# images_clevr/CLEVR_new_001268.png
# images_clevr/CLEVR_new_004944.png
# images_clevr/CLEVR_new_004536.png
# images_clevr/CLEVR_new_008551.png
# images_clevr/CLEVR_new_008923.png
# images_clevr/CLEVR_new_009311.png
# images_clevr/CLEVR_new_005376.png
# images_clevr/CLEVR_new_000428.png
# images_clevr/CLEVR_new_006263.png
# images_clevr/CLEVR_new_007384.png
# images_clevr/CLEVR_new_007423.png
# images_clevr/CLEVR_new_007851.png
# images_clevr/CLEVR_new_009770.png
# images_clevr/CLEVR_new_000049.png
# images_clevr/CLEVR_new_005717.png
# images_clevr/CLEVR_new_008697.png
# images_clevr/CLEVR_new_004157.png
# images_clevr/CLEVR_new_001609.png
# images_clevr/CLEVR_new_008130.png
# images_clevr/CLEVR_new_010969.png
# images_clevr/CLEVR_new_007042.png
# images_clevr/CLEVR_new_006602.png
# images_clevr/CLEVR_new_003465.png
# images_clevr/CLEVR_new_003817.png
# images_clevr/CLEVR_new_002582.png
# images_clevr/CLEVR_new_010022.png
# images_clevr/CLEVR_new_007909.png
# images_clevr/CLEVR_new_002225.png
# images_clevr/CLEVR_new_010785.png
# images_clevr/CLEVR_new_001497.png
# images_clevr/CLEVR_new_001330.png
# images_clevr/CLEVR_new_008409.png
# images_clevr/CLEVR_new_005589.png
# images_clevr/CLEVR_new_009249.png
# images_clevr/CLEVR_new_000902.png
# images_clevr/CLEVR_new_000570.png
# images_clevr/CLEVR_new_010831.png
# images_clevr/CLEVR_new_010443.png
# images_clevr/CLEVR_new_002644.png
# images_clevr/CLEVR_new_011203.png
# images_clevr/CLEVR_new_003004.png
# images_clevr/CLEVR_new_009628.png
# images_clevr/CLEVR_new_000111.png
# images_clevr/CLEVR_new_001751.png
# images_clevr/CLEVR_new_008068.png
# images_clevr/CLEVR_new_001027.png
# images_clevr/CLEVR_new_004779.png
# images_clevr/CLEVR_new_001780.png
# images_clevr/CLEVR_new_005139.png
# images_clevr/CLEVR_new_000667.png
# images_clevr/CLEVR_new_003772.png
# images_clevr/CLEVR_new_010492.png
# images_clevr/CLEVR_new_002132.png
# images_clevr/CLEVR_new_010335.png
# images_clevr/CLEVR_new_002695.png
# images_clevr/CLEVR_new_000206.png
# images_clevr/CLEVR_new_005558.png
# images_clevr/CLEVR_new_009298.png
# images_clevr/CLEVR_new_004318.png
# images_clevr/CLEVR_new_001834.png
# images_clevr/CLEVR_new_001446.png
# images_clevr/CLEVR_new_002553.png
# images_clevr/CLEVR_new_002921.png
# images_clevr/CLEVR_new_010754.png
# images_clevr/CLEVR_new_003313.png
# images_clevr/CLEVR_new_011114.png
# images_clevr/CLEVR_new_001103.png
# images_clevr/CLEVR_new_000743.png
# images_clevr/CLEVR_new_003656.png
# images_clevr/CLEVR_new_006108.png
# images_clevr/CLEVR_new_010211.png
# images_clevr/CLEVR_new_007748.png
# images_clevr/CLEVR_new_002016.png
# images_clevr/CLEVR_new_000485.png
# images_clevr/CLEVR_new_000322.png
# images_clevr/CLEVR_new_009869.png
# images_clevr/CLEVR_new_001562.png
# images_clevr/CLEVR_new_001910.png
# images_clevr/CLEVR_new_010670.png
# images_clevr/CLEVR_new_002805.png
# images_clevr/CLEVR_new_002477.png
# images_clevr/CLEVR_new_007329.png
# images_clevr/CLEVR_new_003590.png
# images_clevr/CLEVR_new_011030.png
# images_clevr/CLEVR_new_006569.png
# images_clevr/CLEVR_new_003237.png
# images_clevr/CLEVR_new_003933.png
# images_clevr/CLEVR_new_003541.png
# images_clevr/CLEVR_new_002301.png
# images_clevr/CLEVR_new_010106.png
# images_clevr/CLEVR_new_001214.png
# images_clevr/CLEVR_new_004938.png
# images_clevr/CLEVR_new_000454.png
# images_clevr/CLEVR_new_000826.png
# images_clevr/CLEVR_new_002760.png
# images_clevr/CLEVR_new_007799.png
# images_clevr/CLEVR_new_010567.png
# images_clevr/CLEVR_new_010915.png
# images_clevr/CLEVR_new_003120.png
# images_clevr/CLEVR_new_011327.png
# images_clevr/CLEVR_new_003687.png
# images_clevr/CLEVR_new_000035.png
# images_clevr/CLEVR_new_000792.png
# images_clevr/CLEVR_new_001675.png
# images_clevr/CLEVR_new_004412.png
# images_clevr/CLEVR_new_004860.png
# images_clevr/CLEVR_new_008807.png
# images_clevr/CLEVR_new_008475.png
# images_clevr/CLEVR_new_001899.png
# images_clevr/CLEVR_new_009235.png
# images_clevr/CLEVR_new_005252.png
# images_clevr/CLEVR_new_009592.png
# images_clevr/CLEVR_new_005987.png
# images_clevr/CLEVR_new_003419.png
# images_clevr/CLEVR_new_006347.png
# images_clevr/CLEVR_new_006892.png
# images_clevr/CLEVR_new_007975.png
# images_clevr/CLEVR_new_007507.png
# images_clevr/CLEVR_new_002259.png
# images_clevr/CLEVR_new_009654.png
# images_clevr/CLEVR_new_005633.png
# images_clevr/CLEVR_new_005194.png
# images_clevr/CLEVR_new_004073.png
# images_clevr/CLEVR_new_008014.png
# images_clevr/CLEVR_new_002638.png
# images_clevr/CLEVR_new_007166.png
# images_clevr/CLEVR_new_010398.png
# images_clevr/CLEVR_new_006726.png
# images_clevr/CLEVR_new_003078.png
# images_clevr/CLEVR_new_006081.png
# images_clevr/CLEVR_new_006050.png
# images_clevr/CLEVR_new_010349.png
# images_clevr/CLEVR_new_007610.png
# images_clevr/CLEVR_new_008762.png
# images_clevr/CLEVR_new_004705.png
# images_clevr/CLEVR_new_009685.png
# images_clevr/CLEVR_new_005145.png
# images_clevr/CLEVR_new_009122.png
# images_clevr/CLEVR_new_010728.png
# images_clevr/CLEVR_new_002288.png
# images_clevr/CLEVR_new_007271.png
# images_clevr/CLEVR_new_006396.png
# images_clevr/CLEVR_new_011168.png
# images_clevr/CLEVR_new_006843.png
# images_clevr/CLEVR_new_006431.png
# images_clevr/CLEVR_new_005283.png
# images_clevr/CLEVR_new_005524.png
# images_clevr/CLEVR_new_005956.png
# images_clevr/CLEVR_new_009931.png
# images_clevr/CLEVR_new_009543.png
# images_clevr/CLEVR_new_008303.png
# images_clevr/CLEVR_new_004364.png
# images_clevr/CLEVR_new_001848.png
# images_clevr/CLEVR_new_000744.png
# images_clevr/CLEVR_new_001104.png
# images_clevr/CLEVR_new_002011.png
# images_clevr/CLEVR_new_010216.png
# images_clevr/CLEVR_new_003651.png
# images_clevr/CLEVR_new_001917.png
# images_clevr/CLEVR_new_001565.png
# images_clevr/CLEVR_new_008989.png
# images_clevr/CLEVR_new_000325.png
# images_clevr/CLEVR_new_005809.png
# images_clevr/CLEVR_new_000482.png
# images_clevr/CLEVR_new_003230.png
# images_clevr/CLEVR_new_003597.png
# images_clevr/CLEVR_new_011037.png
# images_clevr/CLEVR_new_002470.png
# images_clevr/CLEVR_new_002802.png
# images_clevr/CLEVR_new_010677.png
# images_clevr/CLEVR_new_007489.png
# images_clevr/CLEVR_new_010101.png
# images_clevr/CLEVR_new_007458.png
# images_clevr/CLEVR_new_002306.png
# images_clevr/CLEVR_new_003546.png
# images_clevr/CLEVR_new_003934.png
# images_clevr/CLEVR_new_006218.png
# images_clevr/CLEVR_new_000821.png
# images_clevr/CLEVR_new_000453.png
# images_clevr/CLEVR_new_001213.png
# images_clevr/CLEVR_new_008958.png
# images_clevr/CLEVR_new_011320.png
# images_clevr/CLEVR_new_003680.png
# images_clevr/CLEVR_new_006679.png
# images_clevr/CLEVR_new_003127.png
# images_clevr/CLEVR_new_010912.png
# images_clevr/CLEVR_new_010560.png
# images_clevr/CLEVR_new_002767.png
# images_clevr/CLEVR_new_007039.png
# images_clevr/CLEVR_new_001672.png
# images_clevr/CLEVR_new_000795.png
# images_clevr/CLEVR_new_000032.png
# images_clevr/CLEVR_new_009595.png
# images_clevr/CLEVR_new_005980.png
# images_clevr/CLEVR_new_009232.png
# images_clevr/CLEVR_new_005255.png
# images_clevr/CLEVR_new_000979.png
# images_clevr/CLEVR_new_004867.png
# images_clevr/CLEVR_new_004415.png
# images_clevr/CLEVR_new_008472.png
# images_clevr/CLEVR_new_008800.png
# images_clevr/CLEVR_new_010059.png
# images_clevr/CLEVR_new_007500.png
# images_clevr/CLEVR_new_007972.png
# images_clevr/CLEVR_new_006895.png
# images_clevr/CLEVR_new_006340.png
# images_clevr/CLEVR_new_004074.png
# images_clevr/CLEVR_new_008013.png
# images_clevr/CLEVR_new_005193.png
# images_clevr/CLEVR_new_009653.png
# images_clevr/CLEVR_new_005634.png
# images_clevr/CLEVR_new_011278.png
# images_clevr/CLEVR_new_006086.png
# images_clevr/CLEVR_new_006721.png
# images_clevr/CLEVR_new_002198.png
# images_clevr/CLEVR_new_010438.png
# images_clevr/CLEVR_new_007161.png
# images_clevr/CLEVR_new_007617.png
# images_clevr/CLEVR_new_002149.png
# images_clevr/CLEVR_new_003709.png
# images_clevr/CLEVR_new_006057.png
# images_clevr/CLEVR_new_005142.png
# images_clevr/CLEVR_new_009125.png
# images_clevr/CLEVR_new_009682.png
# images_clevr/CLEVR_new_008765.png
# images_clevr/CLEVR_new_004702.png
# images_clevr/CLEVR_new_006436.png
# images_clevr/CLEVR_new_006844.png
# images_clevr/CLEVR_new_003368.png
# images_clevr/CLEVR_new_006391.png
# images_clevr/CLEVR_new_010088.png
# images_clevr/CLEVR_new_002528.png
# images_clevr/CLEVR_new_007276.png
# images_clevr/CLEVR_new_008304.png
# images_clevr/CLEVR_new_004363.png
# images_clevr/CLEVR_new_005951.png
# images_clevr/CLEVR_new_005523.png
# images_clevr/CLEVR_new_009544.png
# images_clevr/CLEVR_new_009936.png
# images_clevr/CLEVR_new_005284.png
# images_clevr/CLEVR_new_007094.png
# images_clevr/CLEVR_new_007733.png
# images_clevr/CLEVR_new_006173.png
# images_clevr/CLEVR_new_005066.png
# images_clevr/CLEVR_new_000738.png
# images_clevr/CLEVR_new_009001.png
# images_clevr/CLEVR_new_004181.png
# images_clevr/CLEVR_new_008641.png
# images_clevr/CLEVR_new_001178.png
# images_clevr/CLEVR_new_004626.png
# images_clevr/CLEVR_new_003999.png
# images_clevr/CLEVR_new_006960.png
# images_clevr/CLEVR_new_006512.png
# images_clevr/CLEVR_new_007887.png
# images_clevr/CLEVR_new_007352.png
# images_clevr/CLEVR_new_008587.png
# images_clevr/CLEVR_new_004992.png
# images_clevr/CLEVR_new_008220.png
# images_clevr/CLEVR_new_004247.png
# images_clevr/CLEVR_new_001519.png
# images_clevr/CLEVR_new_000359.png
# images_clevr/CLEVR_new_005407.png
# images_clevr/CLEVR_new_005875.png
# images_clevr/CLEVR_new_009812.png
# images_clevr/CLEVR_new_009460.png
# images_clevr/CLEVR_new_009316.png
# images_clevr/CLEVR_new_005371.png
# images_clevr/CLEVR_new_000388.png
# images_clevr/CLEVR_new_004531.png
# images_clevr/CLEVR_new_004943.png
# images_clevr/CLEVR_new_008924.png
# images_clevr/CLEVR_new_008556.png
# images_clevr/CLEVR_new_004296.png
# images_clevr/CLEVR_new_007856.png
# images_clevr/CLEVR_new_007424.png
# images_clevr/CLEVR_new_007383.png
# images_clevr/CLEVR_new_003948.png
# images_clevr/CLEVR_new_006264.png
# images_clevr/CLEVR_new_004150.png
# images_clevr/CLEVR_new_008137.png
# images_clevr/CLEVR_new_008690.png
# images_clevr/CLEVR_new_009777.png
# images_clevr/CLEVR_new_005710.png
# images_clevr/CLEVR_new_006605.png
# images_clevr/CLEVR_new_007045.png
# images_clevr/CLEVR_new_002222.png
# images_clevr/CLEVR_new_010782.png
# images_clevr/CLEVR_new_002585.png
# images_clevr/CLEVR_new_010025.png
# images_clevr/CLEVR_new_003810.png
# images_clevr/CLEVR_new_003462.png
# images_clevr/CLEVR_new_005229.png
# images_clevr/CLEVR_new_000577.png
# images_clevr/CLEVR_new_000905.png
# images_clevr/CLEVR_new_001337.png
# images_clevr/CLEVR_new_004469.png
# images_clevr/CLEVR_new_001490.png
# images_clevr/CLEVR_new_003003.png
# images_clevr/CLEVR_new_011204.png
# images_clevr/CLEVR_new_002643.png
# images_clevr/CLEVR_new_010444.png
# images_clevr/CLEVR_new_010836.png
# images_clevr/CLEVR_new_004008.png
# images_clevr/CLEVR_new_001756.png
# images_clevr/CLEVR_new_000116.png
# images_clevr/CLEVR_new_005648.png
# images_clevr/CLEVR_new_009188.png
# images_clevr/CLEVR_new_005699.png
# images_clevr/CLEVR_new_000660.png
# images_clevr/CLEVR_new_009159.png
# images_clevr/CLEVR_new_001787.png
# images_clevr/CLEVR_new_008719.png
# images_clevr/CLEVR_new_001020.png
# images_clevr/CLEVR_new_010332.png
# images_clevr/CLEVR_new_002692.png
# images_clevr/CLEVR_new_010495.png
# images_clevr/CLEVR_new_002135.png
# images_clevr/CLEVR_new_003775.png
# images_clevr/CLEVR_new_008378.png
# images_clevr/CLEVR_new_001441.png
# images_clevr/CLEVR_new_001833.png
# images_clevr/CLEVR_new_000201.png
# images_clevr/CLEVR_new_009538.png
# images_clevr/CLEVR_new_011113.png
# images_clevr/CLEVR_new_006838.png
# images_clevr/CLEVR_new_003314.png
# images_clevr/CLEVR_new_010753.png
# images_clevr/CLEVR_new_002926.png
# images_clevr/CLEVR_new_002554.png
# images_clevr/CLEVR_new_006101.png
# images_clevr/CLEVR_new_007741.png
# images_clevr/CLEVR_new_010218.png
# images_clevr/CLEVR_new_004654.png
# images_clevr/CLEVR_new_008633.png
# images_clevr/CLEVR_new_008194.png
# images_clevr/CLEVR_new_009073.png
# images_clevr/CLEVR_new_005014.png
# images_clevr/CLEVR_new_007320.png
# images_clevr/CLEVR_new_007487.png
# images_clevr/CLEVR_new_010679.png
# images_clevr/CLEVR_new_006912.png
# images_clevr/CLEVR_new_006560.png
# images_clevr/CLEVR_new_011039.png
# images_clevr/CLEVR_new_003599.png
# images_clevr/CLEVR_new_009860.png
# images_clevr/CLEVR_new_009412.png
# images_clevr/CLEVR_new_005475.png
# images_clevr/CLEVR_new_005807.png
# images_clevr/CLEVR_new_004235.png
# images_clevr/CLEVR_new_001919.png
# images_clevr/CLEVR_new_008252.png
# images_clevr/CLEVR_new_004592.png
# images_clevr/CLEVR_new_008987.png
# images_clevr/CLEVR_new_008283.png
# images_clevr/CLEVR_new_008956.png
# images_clevr/CLEVR_new_008524.png
# images_clevr/CLEVR_new_004543.png
# images_clevr/CLEVR_new_004931.png
# images_clevr/CLEVR_new_005303.png
# images_clevr/CLEVR_new_009364.png
# images_clevr/CLEVR_new_003548.png
# images_clevr/CLEVR_new_006216.png
# images_clevr/CLEVR_new_007824.png
# images_clevr/CLEVR_new_007456.png
# images_clevr/CLEVR_new_002308.png
# images_clevr/CLEVR_new_005762.png
# images_clevr/CLEVR_new_009705.png
# images_clevr/CLEVR_new_004685.png
# images_clevr/CLEVR_new_008145.png
# images_clevr/CLEVR_new_004122.png
# images_clevr/CLEVR_new_007790.png
# images_clevr/CLEVR_new_002769.png
# images_clevr/CLEVR_new_007037.png
# images_clevr/CLEVR_new_006677.png
# images_clevr/CLEVR_new_003129.png
# images_clevr/CLEVR_new_003862.png
# images_clevr/CLEVR_new_003410.png
# images_clevr/CLEVR_new_010057.png
# images_clevr/CLEVR_new_002985.png
# images_clevr/CLEVR_new_002250.png
# images_clevr/CLEVR_new_001890.png
# images_clevr/CLEVR_new_001345.png
# images_clevr/CLEVR_new_004869.png
# images_clevr/CLEVR_new_000505.png
# images_clevr/CLEVR_new_000977.png
# images_clevr/CLEVR_new_010436.png
# images_clevr/CLEVR_new_010844.png
# images_clevr/CLEVR_new_002196.png
# images_clevr/CLEVR_new_010391.png
# images_clevr/CLEVR_new_002631.png
# images_clevr/CLEVR_new_006088.png
# images_clevr/CLEVR_new_011276.png
# images_clevr/CLEVR_new_003071.png
# images_clevr/CLEVR_new_000164.png
# images_clevr/CLEVR_new_001083.png
# images_clevr/CLEVR_new_001724.png
# images_clevr/CLEVR_new_001052.png
# images_clevr/CLEVR_new_000612.png
# images_clevr/CLEVR_new_003707.png
# images_clevr/CLEVR_new_006059.png
# images_clevr/CLEVR_new_007619.png
# images_clevr/CLEVR_new_002147.png
# images_clevr/CLEVR_new_010895.png
# images_clevr/CLEVR_new_010340.png
# images_clevr/CLEVR_new_009938.png
# images_clevr/CLEVR_new_000273.png
# images_clevr/CLEVR_new_001433.png
# images_clevr/CLEVR_new_001841.png
# images_clevr/CLEVR_new_001394.png
# images_clevr/CLEVR_new_002954.png
# images_clevr/CLEVR_new_002526.png
# images_clevr/CLEVR_new_007278.png
# images_clevr/CLEVR_new_010086.png
# images_clevr/CLEVR_new_002281.png
# images_clevr/CLEVR_new_010721.png
# images_clevr/CLEVR_new_006438.png
# images_clevr/CLEVR_new_003366.png
# images_clevr/CLEVR_new_011161.png
# images_clevr/CLEVR_new_001176.png
# images_clevr/CLEVR_new_004628.png
# images_clevr/CLEVR_new_000091.png
# images_clevr/CLEVR_new_005068.png
# images_clevr/CLEVR_new_000736.png
# images_clevr/CLEVR_new_003184.png
# images_clevr/CLEVR_new_011383.png
# images_clevr/CLEVR_new_003623.png
# images_clevr/CLEVR_new_010264.png
# images_clevr/CLEVR_new_002063.png
# images_clevr/CLEVR_new_000882.png
# images_clevr/CLEVR_new_000357.png
# images_clevr/CLEVR_new_005409.png
# images_clevr/CLEVR_new_008589.png
# images_clevr/CLEVR_new_004249.png
# images_clevr/CLEVR_new_001965.png
# images_clevr/CLEVR_new_001517.png
# images_clevr/CLEVR_new_007889.png
# images_clevr/CLEVR_new_010605.png
# images_clevr/CLEVR_new_002402.png
# images_clevr/CLEVR_new_002870.png
# images_clevr/CLEVR_new_011045.png
# images_clevr/CLEVR_new_003997.png
# images_clevr/CLEVR_new_003242.png
# images_clevr/CLEVR_new_003534.png
# images_clevr/CLEVR_new_003946.png
# images_clevr/CLEVR_new_011094.png
# images_clevr/CLEVR_new_003293.png
# images_clevr/CLEVR_new_007858.png
# images_clevr/CLEVR_new_002374.png
# images_clevr/CLEVR_new_010173.png
# images_clevr/CLEVR_new_008558.png
# images_clevr/CLEVR_new_001261.png
# images_clevr/CLEVR_new_004298.png
# images_clevr/CLEVR_new_000853.png
# images_clevr/CLEVR_new_000421.png
# images_clevr/CLEVR_new_009318.png
# images_clevr/CLEVR_new_000386.png
# images_clevr/CLEVR_new_002715.png
# images_clevr/CLEVR_new_010960.png
# images_clevr/CLEVR_new_010512.png
# images_clevr/CLEVR_new_003155.png
# images_clevr/CLEVR_new_011352.png
# images_clevr/CLEVR_new_000040.png
# images_clevr/CLEVR_new_009779.png
# images_clevr/CLEVR_new_008139.png
# images_clevr/CLEVR_new_001600.png
# images_clevr/CLEVR_new_008400.png
# images_clevr/CLEVR_new_008872.png
# images_clevr/CLEVR_new_001339.png
# images_clevr/CLEVR_new_004815.png
# images_clevr/CLEVR_new_004467.png
# images_clevr/CLEVR_new_005227.png
# images_clevr/CLEVR_new_000579.png
# images_clevr/CLEVR_new_009240.png
# images_clevr/CLEVR_new_005580.png
# images_clevr/CLEVR_new_009995.png
# images_clevr/CLEVR_new_006332.png
# images_clevr/CLEVR_new_006495.png
# images_clevr/CLEVR_new_007572.png
# images_clevr/CLEVR_new_007900.png
# images_clevr/CLEVR_new_000118.png
# images_clevr/CLEVR_new_005646.png
# images_clevr/CLEVR_new_009621.png
# images_clevr/CLEVR_new_009186.png
# images_clevr/CLEVR_new_008061.png
# images_clevr/CLEVR_new_004006.png
# images_clevr/CLEVR_new_001758.png
# images_clevr/CLEVR_new_007113.png
# images_clevr/CLEVR_new_010838.png
# images_clevr/CLEVR_new_006753.png
# images_clevr/CLEVR_new_006782.png
# images_clevr/CLEVR_new_006025.png
# images_clevr/CLEVR_new_007665.png
# images_clevr/CLEVR_new_001789.png
# images_clevr/CLEVR_new_004770.png
# images_clevr/CLEVR_new_008717.png
# images_clevr/CLEVR_new_005697.png
# images_clevr/CLEVR_new_009157.png
# images_clevr/CLEVR_new_005130.png
# images_clevr/CLEVR_new_002928.png
# images_clevr/CLEVR_new_007204.png
# images_clevr/CLEVR_new_006444.png
# images_clevr/CLEVR_new_006836.png
# images_clevr/CLEVR_new_009291.png
# images_clevr/CLEVR_new_009536.png
# images_clevr/CLEVR_new_009944.png
# images_clevr/CLEVR_new_005923.png
# images_clevr/CLEVR_new_005551.png
# images_clevr/CLEVR_new_004311.png
# images_clevr/CLEVR_new_008376.png
# images_clevr/CLEVR_new_009008.png
# images_clevr/CLEVR_new_000731.png
# images_clevr/CLEVR_new_000096.png
# images_clevr/CLEVR_new_001171.png
# images_clevr/CLEVR_new_008648.png
# images_clevr/CLEVR_new_004188.png
# images_clevr/CLEVR_new_002064.png
# images_clevr/CLEVR_new_010263.png
# images_clevr/CLEVR_new_011384.png
# images_clevr/CLEVR_new_003624.png
# images_clevr/CLEVR_new_003183.png
# images_clevr/CLEVR_new_001510.png
# images_clevr/CLEVR_new_001962.png
# images_clevr/CLEVR_new_008229.png
# images_clevr/CLEVR_new_009469.png
# images_clevr/CLEVR_new_000350.png
# images_clevr/CLEVR_new_000885.png
# images_clevr/CLEVR_new_006969.png
# images_clevr/CLEVR_new_003245.png
# images_clevr/CLEVR_new_011042.png
# images_clevr/CLEVR_new_003990.png
# images_clevr/CLEVR_new_002877.png
# images_clevr/CLEVR_new_002405.png
# images_clevr/CLEVR_new_010602.png
# images_clevr/CLEVR_new_010174.png
# images_clevr/CLEVR_new_002373.png
# images_clevr/CLEVR_new_003294.png
# images_clevr/CLEVR_new_003941.png
# images_clevr/CLEVR_new_003533.png
# images_clevr/CLEVR_new_011093.png
# images_clevr/CLEVR_new_000381.png
# images_clevr/CLEVR_new_005378.png
# images_clevr/CLEVR_new_000426.png
# images_clevr/CLEVR_new_000854.png
# images_clevr/CLEVR_new_001266.png
# images_clevr/CLEVR_new_004538.png
# images_clevr/CLEVR_new_011355.png
# images_clevr/CLEVR_new_003152.png
# images_clevr/CLEVR_new_010515.png
# images_clevr/CLEVR_new_010967.png
# images_clevr/CLEVR_new_002712.png
# images_clevr/CLEVR_new_008699.png
# images_clevr/CLEVR_new_004159.png
# images_clevr/CLEVR_new_001607.png
# images_clevr/CLEVR_new_000047.png
# images_clevr/CLEVR_new_005719.png
# images_clevr/CLEVR_new_005587.png
# images_clevr/CLEVR_new_009992.png
# images_clevr/CLEVR_new_005220.png
# images_clevr/CLEVR_new_009247.png
# images_clevr/CLEVR_new_001499.png
# images_clevr/CLEVR_new_008875.png
# images_clevr/CLEVR_new_008407.png
# images_clevr/CLEVR_new_004460.png
# images_clevr/CLEVR_new_004812.png
# images_clevr/CLEVR_new_007907.png
# images_clevr/CLEVR_new_007575.png
# images_clevr/CLEVR_new_006492.png
# images_clevr/CLEVR_new_003819.png
# images_clevr/CLEVR_new_006335.png
# images_clevr/CLEVR_new_008066.png
# images_clevr/CLEVR_new_004001.png
# images_clevr/CLEVR_new_009181.png
# images_clevr/CLEVR_new_005641.png
# images_clevr/CLEVR_new_009626.png
# images_clevr/CLEVR_new_006754.png
# images_clevr/CLEVR_new_007114.png
# images_clevr/CLEVR_new_007662.png
# images_clevr/CLEVR_new_006022.png
# images_clevr/CLEVR_new_006785.png
# images_clevr/CLEVR_new_009150.png
# images_clevr/CLEVR_new_005137.png
# images_clevr/CLEVR_new_000669.png
# images_clevr/CLEVR_new_005690.png
# images_clevr/CLEVR_new_001029.png
# images_clevr/CLEVR_new_004777.png
# images_clevr/CLEVR_new_008710.png
# images_clevr/CLEVR_new_006831.png
# images_clevr/CLEVR_new_006443.png
# images_clevr/CLEVR_new_007203.png
# images_clevr/CLEVR_new_004316.png
# images_clevr/CLEVR_new_001448.png
# images_clevr/CLEVR_new_008371.png
# images_clevr/CLEVR_new_009943.png
# images_clevr/CLEVR_new_009531.png
# images_clevr/CLEVR_new_000208.png
# images_clevr/CLEVR_new_005556.png
# images_clevr/CLEVR_new_005924.png
# images_clevr/CLEVR_new_009296.png
# images_clevr/CLEVR_new_007746.png
# images_clevr/CLEVR_new_002018.png
# images_clevr/CLEVR_new_003658.png
# images_clevr/CLEVR_new_006106.png
# images_clevr/CLEVR_new_009074.png
# images_clevr/CLEVR_new_005013.png
# images_clevr/CLEVR_new_008193.png
# images_clevr/CLEVR_new_004653.png
# images_clevr/CLEVR_new_008634.png
# images_clevr/CLEVR_new_006567.png
# images_clevr/CLEVR_new_006915.png
# images_clevr/CLEVR_new_003239.png
# images_clevr/CLEVR_new_007480.png
# images_clevr/CLEVR_new_002479.png
# images_clevr/CLEVR_new_007327.png
# images_clevr/CLEVR_new_004595.png
# images_clevr/CLEVR_new_008980.png
# images_clevr/CLEVR_new_004232.png
# images_clevr/CLEVR_new_008255.png
# images_clevr/CLEVR_new_009415.png
# images_clevr/CLEVR_new_009867.png
# images_clevr/CLEVR_new_005800.png
# images_clevr/CLEVR_new_005472.png
# images_clevr/CLEVR_new_005304.png
# images_clevr/CLEVR_new_000828.png
# images_clevr/CLEVR_new_009363.png
# images_clevr/CLEVR_new_008523.png
# images_clevr/CLEVR_new_008951.png
# images_clevr/CLEVR_new_004936.png
# images_clevr/CLEVR_new_004544.png
# images_clevr/CLEVR_new_008284.png
# images_clevr/CLEVR_new_007451.png
# images_clevr/CLEVR_new_007823.png
# images_clevr/CLEVR_new_010108.png
# images_clevr/CLEVR_new_006211.png
# images_clevr/CLEVR_new_008142.png
# images_clevr/CLEVR_new_004125.png
# images_clevr/CLEVR_new_004682.png
# images_clevr/CLEVR_new_005765.png
# images_clevr/CLEVR_new_009702.png
# images_clevr/CLEVR_new_006670.png
# images_clevr/CLEVR_new_003689.png
# images_clevr/CLEVR_new_011329.png
# images_clevr/CLEVR_new_007030.png
# images_clevr/CLEVR_new_010569.png
# images_clevr/CLEVR_new_007797.png
# images_clevr/CLEVR_new_007509.png
# images_clevr/CLEVR_new_002257.png
# images_clevr/CLEVR_new_010050.png
# images_clevr/CLEVR_new_002982.png
# images_clevr/CLEVR_new_003417.png
# images_clevr/CLEVR_new_003865.png
# images_clevr/CLEVR_new_006349.png
# images_clevr/CLEVR_new_000970.png
# images_clevr/CLEVR_new_000502.png
# images_clevr/CLEVR_new_005989.png
# images_clevr/CLEVR_new_008809.png
# ...
# images_clevr/CLEVR_new_010437.png
# images_clevr/CLEVR_new_010845.png
# images_clevr/CLEVR_new_003070.png
# images_clevr/CLEVR_new_011277.png
# images_clevr/CLEVR_new_006089.png
# images_clevr/CLEVR_new_003706.png
# images_clevr/CLEVR_new_006058.png
# images_clevr/CLEVR_new_010341.png
# images_clevr/CLEVR_new_010894.png
# images_clevr/CLEVR_new_007618.png
# images_clevr/CLEVR_new_002146.png
# images_clevr/CLEVR_new_001053.png
# images_clevr/CLEVR_new_000613.png
# images_clevr/CLEVR_new_010720.png
# images_clevr/CLEVR_new_002280.png
# images_clevr/CLEVR_new_010087.png
# images_clevr/CLEVR_new_002955.png
# images_clevr/CLEVR_new_002527.png
# images_clevr/CLEVR_new_007279.png
# images_clevr/CLEVR_new_011160.png
# images_clevr/CLEVR_new_006439.png
# images_clevr/CLEVR_new_003367.png
# images_clevr/CLEVR_new_000272.png
# images_clevr/CLEVR_new_009939.png
# images_clevr/CLEVR_new_001395.png
# images_clevr/CLEVR_new_001432.png
# images_clevr/CLEVR_new_001840.png
# images_clevr/CLEVR_new_003622.png
# images_clevr/CLEVR_new_011382.png
# images_clevr/CLEVR_new_003185.png
# images_clevr/CLEVR_new_002062.png
# images_clevr/CLEVR_new_010265.png
# images_clevr/CLEVR_new_001177.png
# images_clevr/CLEVR_new_004629.png
# images_clevr/CLEVR_new_005069.png
# images_clevr/CLEVR_new_000737.png
# images_clevr/CLEVR_new_000090.png
# images_clevr/CLEVR_new_002403.png
# images_clevr/CLEVR_new_002871.png
# images_clevr/CLEVR_new_010604.png
# images_clevr/CLEVR_new_007888.png
# images_clevr/CLEVR_new_003243.png
# images_clevr/CLEVR_new_003996.png
# images_clevr/CLEVR_new_011044.png
# images_clevr/CLEVR_new_000356.png
# images_clevr/CLEVR_new_005408.png
# images_clevr/CLEVR_new_000883.png
# images_clevr/CLEVR_new_004248.png
# images_clevr/CLEVR_new_001964.png
# images_clevr/CLEVR_new_001516.png
# images_clevr/CLEVR_new_008588.png
# images_clevr/CLEVR_new_004299.png
# images_clevr/CLEVR_new_001260.png
# images_clevr/CLEVR_new_008559.png
# images_clevr/CLEVR_new_000387.png
# images_clevr/CLEVR_new_009319.png
# images_clevr/CLEVR_new_000852.png
# images_clevr/CLEVR_new_000420.png
# images_clevr/CLEVR_new_003292.png
# images_clevr/CLEVR_new_011095.png
# images_clevr/CLEVR_new_003535.png
# images_clevr/CLEVR_new_003947.png
# images_clevr/CLEVR_new_010172.png
# images_clevr/CLEVR_new_007859.png
# images_clevr/CLEVR_new_002375.png
# images_clevr/CLEVR_new_009778.png
# images_clevr/CLEVR_new_000041.png
# images_clevr/CLEVR_new_001601.png
# images_clevr/CLEVR_new_008138.png
# images_clevr/CLEVR_new_010961.png
# images_clevr/CLEVR_new_010513.png
# images_clevr/CLEVR_new_002714.png
# images_clevr/CLEVR_new_011353.png
# images_clevr/CLEVR_new_003154.png
# images_clevr/CLEVR_new_006494.png
# images_clevr/CLEVR_new_006333.png
# images_clevr/CLEVR_new_007573.png
# images_clevr/CLEVR_new_007901.png
# images_clevr/CLEVR_new_001338.png
# images_clevr/CLEVR_new_004814.png
# images_clevr/CLEVR_new_004466.png
# images_clevr/CLEVR_new_008401.png
# images_clevr/CLEVR_new_008873.png
# images_clevr/CLEVR_new_009994.png
# images_clevr/CLEVR_new_005581.png
# images_clevr/CLEVR_new_009241.png
# images_clevr/CLEVR_new_005226.png
# images_clevr/CLEVR_new_000578.png
# images_clevr/CLEVR_new_010839.png
# images_clevr/CLEVR_new_007112.png
# images_clevr/CLEVR_new_006752.png
# images_clevr/CLEVR_new_009187.png
# images_clevr/CLEVR_new_009620.png
# images_clevr/CLEVR_new_000119.png
# images_clevr/CLEVR_new_005647.png
# images_clevr/CLEVR_new_004007.png
# images_clevr/CLEVR_new_001759.png
# images_clevr/CLEVR_new_008060.png
# images_clevr/CLEVR_new_008716.png
# images_clevr/CLEVR_new_004771.png
# images_clevr/CLEVR_new_001788.png
# images_clevr/CLEVR_new_005131.png
# images_clevr/CLEVR_new_009156.png
# images_clevr/CLEVR_new_005696.png
# images_clevr/CLEVR_new_006024.png
# images_clevr/CLEVR_new_006783.png
# images_clevr/CLEVR_new_007664.png
# images_clevr/CLEVR_new_005922.png
# images_clevr/CLEVR_new_005550.png
# images_clevr/CLEVR_new_009537.png
# images_clevr/CLEVR_new_009945.png
# images_clevr/CLEVR_new_009290.png
# images_clevr/CLEVR_new_008377.png
# images_clevr/CLEVR_new_004310.png
# images_clevr/CLEVR_new_002929.png
# images_clevr/CLEVR_new_007205.png
# images_clevr/CLEVR_new_006445.png
# images_clevr/CLEVR_new_006837.png
# images_clevr/CLEVR_new_010217.png
# images_clevr/CLEVR_new_002010.png
# images_clevr/CLEVR_new_003650.png
# images_clevr/CLEVR_new_000745.png
# images_clevr/CLEVR_new_001105.png
# images_clevr/CLEVR_new_011036.png
# images_clevr/CLEVR_new_003596.png
# images_clevr/CLEVR_new_003231.png
# images_clevr/CLEVR_new_007488.png
# images_clevr/CLEVR_new_010676.png
# images_clevr/CLEVR_new_002471.png
# images_clevr/CLEVR_new_002803.png
# images_clevr/CLEVR_new_008988.png
# images_clevr/CLEVR_new_001916.png
# images_clevr/CLEVR_new_001564.png
# images_clevr/CLEVR_new_000483.png
# images_clevr/CLEVR_new_000324.png
# images_clevr/CLEVR_new_005808.png
# images_clevr/CLEVR_new_000820.png
# images_clevr/CLEVR_new_000452.png
# images_clevr/CLEVR_new_008959.png
# images_clevr/CLEVR_new_001212.png
# images_clevr/CLEVR_new_007459.png
# images_clevr/CLEVR_new_002307.png
# images_clevr/CLEVR_new_010100.png
# images_clevr/CLEVR_new_003547.png
# images_clevr/CLEVR_new_003935.png
# images_clevr/CLEVR_new_006219.png
# images_clevr/CLEVR_new_001673.png
# images_clevr/CLEVR_new_000033.png
# images_clevr/CLEVR_new_000794.png
# images_clevr/CLEVR_new_006678.png
# images_clevr/CLEVR_new_003126.png
# images_clevr/CLEVR_new_003681.png
# images_clevr/CLEVR_new_011321.png
# images_clevr/CLEVR_new_002766.png
# images_clevr/CLEVR_new_007038.png
# images_clevr/CLEVR_new_010913.png
# images_clevr/CLEVR_new_010561.png
# images_clevr/CLEVR_new_007501.png
# images_clevr/CLEVR_new_007973.png
# images_clevr/CLEVR_new_010058.png
# images_clevr/CLEVR_new_006341.png
# images_clevr/CLEVR_new_006894.png
# images_clevr/CLEVR_new_005254.png
# images_clevr/CLEVR_new_000978.png
# images_clevr/CLEVR_new_009233.png
# images_clevr/CLEVR_new_005981.png
# images_clevr/CLEVR_new_009594.png
# images_clevr/CLEVR_new_008473.png
# images_clevr/CLEVR_new_008801.png
# images_clevr/CLEVR_new_004866.png
# images_clevr/CLEVR_new_004414.png
# images_clevr/CLEVR_new_006720.png
# images_clevr/CLEVR_new_006087.png
# images_clevr/CLEVR_new_011279.png
# images_clevr/CLEVR_new_007160.png
# images_clevr/CLEVR_new_010439.png
# images_clevr/CLEVR_new_002199.png
# images_clevr/CLEVR_new_008012.png
# images_clevr/CLEVR_new_004075.png
# images_clevr/CLEVR_new_005635.png
# images_clevr/CLEVR_new_009652.png
# images_clevr/CLEVR_new_005192.png
# images_clevr/CLEVR_new_009683.png
# images_clevr/CLEVR_new_009124.png
# images_clevr/CLEVR_new_005143.png
# images_clevr/CLEVR_new_004703.png
# images_clevr/CLEVR_new_008764.png
# images_clevr/CLEVR_new_007616.png
# images_clevr/CLEVR_new_002148.png
# images_clevr/CLEVR_new_003708.png
# images_clevr/CLEVR_new_006056.png
# images_clevr/CLEVR_new_004362.png
# images_clevr/CLEVR_new_008305.png
# images_clevr/CLEVR_new_005285.png
# images_clevr/CLEVR_new_009545.png
# images_clevr/CLEVR_new_009937.png
# images_clevr/CLEVR_new_005950.png
# images_clevr/CLEVR_new_005522.png
# images_clevr/CLEVR_new_006390.png
# images_clevr/CLEVR_new_006437.png
# images_clevr/CLEVR_new_006845.png
# images_clevr/CLEVR_new_003369.png
# images_clevr/CLEVR_new_002529.png
# images_clevr/CLEVR_new_007277.png
# images_clevr/CLEVR_new_010089.png
# images_clevr/CLEVR_new_009000.png
# images_clevr/CLEVR_new_005067.png
# images_clevr/CLEVR_new_000739.png
# images_clevr/CLEVR_new_001179.png
# images_clevr/CLEVR_new_004627.png
# images_clevr/CLEVR_new_008640.png
# images_clevr/CLEVR_new_004180.png
# images_clevr/CLEVR_new_007732.png
# images_clevr/CLEVR_new_007095.png
# images_clevr/CLEVR_new_006172.png
# images_clevr/CLEVR_new_004246.png
# images_clevr/CLEVR_new_001518.png
# images_clevr/CLEVR_new_008221.png
# images_clevr/CLEVR_new_004993.png
# images_clevr/CLEVR_new_008586.png
# images_clevr/CLEVR_new_009813.png
# images_clevr/CLEVR_new_009461.png
# images_clevr/CLEVR_new_000358.png
# images_clevr/CLEVR_new_005406.png
# images_clevr/CLEVR_new_005874.png
# images_clevr/CLEVR_new_006961.png
# images_clevr/CLEVR_new_006513.png
# images_clevr/CLEVR_new_003998.png
# images_clevr/CLEVR_new_007353.png
# images_clevr/CLEVR_new_007886.png
# images_clevr/CLEVR_new_007382.png
# images_clevr/CLEVR_new_007857.png
# images_clevr/CLEVR_new_007425.png
# images_clevr/CLEVR_new_003949.png
# images_clevr/CLEVR_new_006265.png
# images_clevr/CLEVR_new_000389.png
# images_clevr/CLEVR_new_005370.png
# images_clevr/CLEVR_new_009317.png
# images_clevr/CLEVR_new_004297.png
# images_clevr/CLEVR_new_008925.png
# images_clevr/CLEVR_new_008557.png
# images_clevr/CLEVR_new_004530.png
# images_clevr/CLEVR_new_004942.png
# images_clevr/CLEVR_new_006604.png
# images_clevr/CLEVR_new_007044.png
# images_clevr/CLEVR_new_008691.png
# images_clevr/CLEVR_new_008136.png
# images_clevr/CLEVR_new_004151.png
# images_clevr/CLEVR_new_005711.png
# images_clevr/CLEVR_new_009776.png
# images_clevr/CLEVR_new_005228.png
# images_clevr/CLEVR_new_000576.png
# images_clevr/CLEVR_new_000904.png
# images_clevr/CLEVR_new_001491.png
# images_clevr/CLEVR_new_001336.png
# images_clevr/CLEVR_new_004468.png
# images_clevr/CLEVR_new_010024.png
# images_clevr/CLEVR_new_002584.png
# images_clevr/CLEVR_new_010783.png
# images_clevr/CLEVR_new_002223.png
# images_clevr/CLEVR_new_003811.png
# images_clevr/CLEVR_new_003463.png
# images_clevr/CLEVR_new_004009.png
# images_clevr/CLEVR_new_001757.png
# images_clevr/CLEVR_new_009189.png
# images_clevr/CLEVR_new_000117.png
# images_clevr/CLEVR_new_005649.png
# images_clevr/CLEVR_new_011205.png
# images_clevr/CLEVR_new_003002.png
# images_clevr/CLEVR_new_010445.png
# images_clevr/CLEVR_new_010837.png
# images_clevr/CLEVR_new_002642.png
# images_clevr/CLEVR_new_002134.png
# images_clevr/CLEVR_new_010494.png
# images_clevr/CLEVR_new_002693.png
# images_clevr/CLEVR_new_010333.png
# images_clevr/CLEVR_new_003774.png
# images_clevr/CLEVR_new_009158.png
# images_clevr/CLEVR_new_000661.png
# images_clevr/CLEVR_new_005698.png
# images_clevr/CLEVR_new_001021.png
# images_clevr/CLEVR_new_008718.png
# images_clevr/CLEVR_new_001786.png
# images_clevr/CLEVR_new_006839.png
# images_clevr/CLEVR_new_003315.png
# images_clevr/CLEVR_new_011112.png
# images_clevr/CLEVR_new_002927.png
# images_clevr/CLEVR_new_002555.png
# images_clevr/CLEVR_new_010752.png
# images_clevr/CLEVR_new_001440.png
# images_clevr/CLEVR_new_001832.png
# images_clevr/CLEVR_new_008379.png
# images_clevr/CLEVR_new_009539.png
# images_clevr/CLEVR_new_000200.png
# images_clevr/CLEVR_new_004187.png
# images_clevr/CLEVR_new_004620.png
# images_clevr/CLEVR_new_008647.png
# images_clevr/CLEVR_new_000099.png
# images_clevr/CLEVR_new_009007.png
# images_clevr/CLEVR_new_005060.png
# images_clevr/CLEVR_new_006175.png
# images_clevr/CLEVR_new_007092.png
# images_clevr/CLEVR_new_007735.png
# images_clevr/CLEVR_new_009466.png
# images_clevr/CLEVR_new_009814.png
# images_clevr/CLEVR_new_005873.png
# images_clevr/CLEVR_new_005401.png
# images_clevr/CLEVR_new_004994.png
# images_clevr/CLEVR_new_008581.png
# images_clevr/CLEVR_new_004241.png
# images_clevr/CLEVR_new_008226.png
# images_clevr/CLEVR_new_007881.png
# images_clevr/CLEVR_new_002878.png
# images_clevr/CLEVR_new_007354.png
# images_clevr/CLEVR_new_006514.png
# images_clevr/CLEVR_new_006966.png
# images_clevr/CLEVR_new_006262.png
# images_clevr/CLEVR_new_007422.png
# images_clevr/CLEVR_new_007850.png
# images_clevr/CLEVR_new_007385.png
# images_clevr/CLEVR_new_008550.png
# images_clevr/CLEVR_new_008922.png
# images_clevr/CLEVR_new_001269.png
# images_clevr/CLEVR_new_004945.png
# images_clevr/CLEVR_new_004537.png
# images_clevr/CLEVR_new_004290.png
# images_clevr/CLEVR_new_005377.png
# images_clevr/CLEVR_new_000429.png
# images_clevr/CLEVR_new_009310.png
# images_clevr/CLEVR_new_007043.png
# images_clevr/CLEVR_new_010968.png
# images_clevr/CLEVR_new_006603.png
# images_clevr/CLEVR_new_000048.png
# images_clevr/CLEVR_new_005716.png
# images_clevr/CLEVR_new_009771.png
# images_clevr/CLEVR_new_008131.png
# images_clevr/CLEVR_new_004156.png
# images_clevr/CLEVR_new_001608.png
# images_clevr/CLEVR_new_008696.png
# images_clevr/CLEVR_new_008408.png
# images_clevr/CLEVR_new_001331.png
# images_clevr/CLEVR_new_001496.png
# images_clevr/CLEVR_new_000903.png
# images_clevr/CLEVR_new_000571.png
# images_clevr/CLEVR_new_009248.png
# images_clevr/CLEVR_new_005588.png
# images_clevr/CLEVR_new_003464.png
# images_clevr/CLEVR_new_003816.png
# images_clevr/CLEVR_new_010784.png
# images_clevr/CLEVR_new_007908.png
# images_clevr/CLEVR_new_002224.png
# images_clevr/CLEVR_new_010023.png
# images_clevr/CLEVR_new_002583.png
# images_clevr/CLEVR_new_000110.png
# images_clevr/CLEVR_new_009629.png
# images_clevr/CLEVR_new_008069.png
# images_clevr/CLEVR_new_001750.png
# images_clevr/CLEVR_new_002645.png
# images_clevr/CLEVR_new_010830.png
# images_clevr/CLEVR_new_010442.png
# images_clevr/CLEVR_new_003005.png
# images_clevr/CLEVR_new_011202.png
# images_clevr/CLEVR_new_003773.png
# images_clevr/CLEVR_new_002694.png
# images_clevr/CLEVR_new_010334.png
# images_clevr/CLEVR_new_002133.png
# images_clevr/CLEVR_new_010493.png
# images_clevr/CLEVR_new_001781.png
# images_clevr/CLEVR_new_001026.png
# images_clevr/CLEVR_new_004778.png
# images_clevr/CLEVR_new_005138.png
# images_clevr/CLEVR_new_000666.png
# images_clevr/CLEVR_new_010755.png
# images_clevr/CLEVR_new_002552.png
# images_clevr/CLEVR_new_002920.png
# images_clevr/CLEVR_new_011115.png
# images_clevr/CLEVR_new_003312.png
# images_clevr/CLEVR_new_009299.png
# images_clevr/CLEVR_new_000207.png
# images_clevr/CLEVR_new_005559.png
# images_clevr/CLEVR_new_004319.png
# images_clevr/CLEVR_new_001835.png
# images_clevr/CLEVR_new_001447.png
# images_clevr/CLEVR_new_003657.png
# images_clevr/CLEVR_new_006109.png
# images_clevr/CLEVR_new_007749.png
# images_clevr/CLEVR_new_002017.png
# images_clevr/CLEVR_new_010210.png
# images_clevr/CLEVR_new_001102.png
# images_clevr/CLEVR_new_000742.png
# images_clevr/CLEVR_new_002804.png
# images_clevr/CLEVR_new_002476.png
# images_clevr/CLEVR_new_007328.png
# images_clevr/CLEVR_new_010671.png
# images_clevr/CLEVR_new_006568.png
# images_clevr/CLEVR_new_003236.png
# images_clevr/CLEVR_new_011031.png
# images_clevr/CLEVR_new_003591.png
# images_clevr/CLEVR_new_009868.png
# images_clevr/CLEVR_new_000323.png
# images_clevr/CLEVR_new_000484.png
# images_clevr/CLEVR_new_001563.png
# images_clevr/CLEVR_new_001911.png
# images_clevr/CLEVR_new_001215.png
# images_clevr/CLEVR_new_004939.png
# images_clevr/CLEVR_new_000455.png
# images_clevr/CLEVR_new_000827.png
# images_clevr/CLEVR_new_003932.png
# images_clevr/CLEVR_new_003540.png
# images_clevr/CLEVR_new_010107.png
# images_clevr/CLEVR_new_002300.png
# images_clevr/CLEVR_new_000793.png
# images_clevr/CLEVR_new_000034.png
# images_clevr/CLEVR_new_001674.png
# images_clevr/CLEVR_new_010566.png
# images_clevr/CLEVR_new_010914.png
# images_clevr/CLEVR_new_007798.png
# images_clevr/CLEVR_new_002761.png
# images_clevr/CLEVR_new_003686.png
# images_clevr/CLEVR_new_011326.png
# images_clevr/CLEVR_new_003121.png
# images_clevr/CLEVR_new_006893.png
# images_clevr/CLEVR_new_003418.png
# images_clevr/CLEVR_new_006346.png
# images_clevr/CLEVR_new_007974.png
# images_clevr/CLEVR_new_007506.png
# images_clevr/CLEVR_new_002258.png
# images_clevr/CLEVR_new_001898.png
# images_clevr/CLEVR_new_008806.png
# images_clevr/CLEVR_new_008474.png
# images_clevr/CLEVR_new_004413.png
# images_clevr/CLEVR_new_004861.png
# images_clevr/CLEVR_new_005986.png
# images_clevr/CLEVR_new_009593.png
# images_clevr/CLEVR_new_005253.png
# images_clevr/CLEVR_new_009234.png
# images_clevr/CLEVR_new_010399.png
# images_clevr/CLEVR_new_002639.png
# images_clevr/CLEVR_new_007167.png
# images_clevr/CLEVR_new_006080.png
# images_clevr/CLEVR_new_006727.png
# images_clevr/CLEVR_new_003079.png
# images_clevr/CLEVR_new_005195.png
# images_clevr/CLEVR_new_005632.png
# images_clevr/CLEVR_new_009655.png
# images_clevr/CLEVR_new_008015.png
# images_clevr/CLEVR_new_004072.png
# images_clevr/CLEVR_new_004704.png
# images_clevr/CLEVR_new_008763.png
# images_clevr/CLEVR_new_009123.png
# images_clevr/CLEVR_new_005144.png
# images_clevr/CLEVR_new_009684.png
# images_clevr/CLEVR_new_006051.png
# images_clevr/CLEVR_new_007611.png
# images_clevr/CLEVR_new_010348.png
# images_clevr/CLEVR_new_009930.png
# images_clevr/CLEVR_new_009542.png
# images_clevr/CLEVR_new_005525.png
# images_clevr/CLEVR_new_005957.png
# images_clevr/CLEVR_new_005282.png
# images_clevr/CLEVR_new_004365.png
# images_clevr/CLEVR_new_001849.png
# images_clevr/CLEVR_new_008302.png
# images_clevr/CLEVR_new_007270.png
# images_clevr/CLEVR_new_002289.png
# images_clevr/CLEVR_new_010729.png
# images_clevr/CLEVR_new_006842.png
# images_clevr/CLEVR_new_006430.png
# images_clevr/CLEVR_new_011169.png
# images_clevr/CLEVR_new_006397.png

# %%
import os
import os.path as osp
import numpy as np
import json

import torchvision.transforms.functional as TF
import random

from PIL import Image
import torch.utils.data as data
import torch
import cv2
from torchvision import transforms
import glob

try:
    import multi_dsprites
    import tetrominoes
    import tensorflow.compat.v1 as tf
    tf.disable_v2_behavior()
except:
    pass

from glob import glob

from imageio import imread
from skimage.transform import resize as imresize
from torchvision.datasets import FashionMNIST


class GaussianBlur(object):

    def __init__(self, min=0.1, max=2.0, kernel_size=9):
        self.min = min
        self.max = max
        self.kernel_size = kernel_size

    def __call__(self, sample):
        sample = np.array(sample)

        # blur the image with a 50% chance
        prob = np.random.random_sample()

        if prob < 0.5:
            sigma = (self.max - self.min) * np.random.random_sample() + self.min
            sample = cv2.GaussianBlur(sample, (self.kernel_size, self.kernel_size), sigma)

        return sample


class IntPhysDataset(data.Dataset):
    """This dataset class can load a set of images specified by the path --dataroot /path/to/data.

    It can be used for generating CycleGAN results only for one side with the model option '-model test'.
    """

    def __init__(self, args):
        """Initialize this dataset class.

        Parameters:
            opt (Option class) -- stores all the experiment flags; needs to be a subclass of BaseOptions
        """
        train_path = "/private/home/yilundu/dataset/intphys"
        # train_path = "/data/vision/billf/scratch/jerrymei/newIntPhys/render/output/train_v7"
        # random.seed(rank_idx)

        p = train_path

        dirs = os.listdir(p)
        files = []
        depth_files = []

        for d in dirs:
            base_path = osp.join(p, d, 'imgs')
            ims = os.listdir(base_path)
            ims = sorted(ims)
            ims = ims

            im_paths = [osp.join(base_path, im) for im in ims]
            files.append(im_paths)

        self.args = args
        self.A_paths = files
        self.D_paths = depth_files
        self.frames = 2
        self.im_size = args.im_size
        self.temporal = args.temporal


    def __getitem__(self, index):
        """Return a data point and its metadata information.

        Parameters:
            index - - a random integer for data indexing

        Returns a dictionary that contains A and A_paths
            A(tensor) - - an image in one domain
            A_paths(str) - - the path of the image
        """

        args = self.args

        if args.single:
            index = 0

        index = index % len(self.A_paths)

        A_path = self.A_paths[index]
        ix = random.randint(0, len(A_path) - 20)

        ix_next = ix + random.randint(0, 19)

        im = imread(A_path[ix])[:, :, :3]
        im_next = imread(A_path[ix_next])[:, :, :3]

        im = imresize(im, (64, 64))[:, :, :3]
        im_next = imresize(im_next, (64, 64))[:, :, :3]

        im = torch.Tensor(im).permute(2, 0, 1)
        im_next = torch.Tensor(im_next).permute(2, 0, 1)

        if self.temporal:
            im = torch.stack([im, im_next], dim=0)

        return im, index


    def __len__(self):
        """Return the total number of images in the dataset."""
        return 1000000


class ToyDataset(data.Dataset):
    """Constructs a dataset with N circles, N is the number of components set by flags"""

    def __init__(self, opt):
        """Initialize this dataset class.

        Parameters:
            opt (Option class) -- stores all the experiment flags; needs to be a subclass of BaseOptions
        """
        self.opt = opt
        self.components = 3

        # self.nsample = 10000
        self.samples = []



    def __getitem__(self, index):
        """Return a data point and its metadata information.

        Parameters:
            index - - a random integer for data indexing

        Returns a dictionary that contains A and A_paths
            A(tensor) - - an image in one domain
            A_paths(str) - - the path of the image
        """

        FLAGS = self.opt
        A = np.zeros((3, 64, 64))
        dot_size = 5

        intersects = []

        for i in range(self.components):
            while True:
                x, y = random.randint(dot_size, 64 - dot_size), random.randint(dot_size, 64 - dot_size)

                valid = True
                for xi, yi in intersects:
                    if (abs(x - xi) < 2 * dot_size)  and (abs(y - yi) < 2 * dot_size):
                        valid = False
                        break

                if valid:
                    A[i, x-dot_size:x+dot_size, y-dot_size:y+dot_size] = 0.8
                    intersects.append((x, y))
                    break

        A = torch.Tensor(A)

        return A, index

    def __len__(self):
        """Return the total number of images in the dataset."""
        # Dataset is always randomly generated
        return 1000000


# class Blender(data.Dataset):
#     def __init__(self, stage=0):
#         self.path = "/private/home/yilundu/sandbox/data/blender/continual/test_rotation"
#
#     def __len__(self):
#         return 10000
#
#     def __getitem__(self, index):
#         im = imread(osp.join(self.path, "r_{}.png".format(index)))
#         im = imresize(im, (64, 64))[:, :, :3]
#         im = im / 255.
#
#         im = torch.Tensor(im).permute(2, 0, 1)
#
#         return im, index

# class Blender(data.Dataset):
#     def __init__(self, stage=0):
#         self.path = "/private/home/yilundu/sandbox/data/CLEVR_v1.0/images/train"
#         self.images = glob.glob(self.path + "/*.png")
#
#     def __len__(self):
#         return len(self.images)
#
#     def __getitem__(self, index):
#         im_path = self.images[index]
#         im = imread(im_path)
#         im = imresize(im, (64, 64))[:, :, :3]
#         im = im / 255.
#
#         im = torch.Tensor(im).permute(2, 0, 1)
#
#         return im, index

class Blender(data.Dataset):
    def __init__(self, stage=0):
        self.path = "/private/home/yilundu/dataset/shop_vrb/images/train"
        self.images = glob.glob(self.path + "/*.png")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, index):
        im_path = self.images[index]
        im = imread(im_path)
        im = imresize(im, (64, 64))[:, :, :3]
        im = im / 255.

        im = torch.Tensor(im).permute(2, 0, 1)

        return im, index

class FashionMnistDataset(data.Dataset):
    """
    A PyTorch Dataset class for FashionMNIST, similar to the other datasets
    in this file. It leverages the torchvision FashionMNIST dataset.
    """

    def __init__(self, args, root, train=True, transform=None, download=True, im_size=64):
        """
        Initializes the FashionMNIST dataset.

        Args:
            root (string): Root directory where the FashionMNIST data is stored.
            train (bool, optional): If True, creates dataset from training set, otherwise
                                     creates from test set. Defaults to True.
            transform (callable, optional): A function/transform that takes in an PIL image
                                            and returns a transformed version.
                                            E.g, ``transforms.RandomCrop``
            download (bool, optional): If true, downloads the dataset from the internet and
                                      puts it in root directory.  If dataset is already downloaded,
                                      it is not downloaded again.
            im_size (int, optional):  The size to resize the images to. Defaults to 64.
        """


        self.root = "/content/sample_data"
        self.fashion_mnist = FashionMNIST(root=root, train=train, download=download, transform=transform)  # Download and load FashionMNIST
        self.im_size = im_size
        self.transform = transform if transform is not None else transforms.ToTensor() # default to ToTensor if no transform provided
        #self.resize_transform = transforms.Resize((im_size, im_size)) # Resize images to desired size
        #self.to_pil = transforms.ToPILImage() # Convert tensor to PIL for resizing
        self.transform = transform
    def __len__(self):
        """Returns the total number of images in the dataset."""
        return len(self.fashion_mnist)

    def __getitem__(self, index):
        """
        Returns a data point and its metadata information.

        Args:
            index (int): Index of the data point.

        Returns:
            tuple: (image, label) where:
                image (torch.Tensor):  FashionMNIST image as a PyTorch tensor, resized to im_size x im_size.
                label (int):  Corresponding class label.
        """
        #image, label = self.fashion_mnist[index]
        # Convert to PIL image, resize, and then convert to tensor.  Handles grayscale correctly.
        #image = self.to_pil(image)
        #image = self.resize_transform(image) # Resize the image
        #print(type(image))
        #image = self.transform(image)
        #print(type(image))
        #image = self.transform(image) # Apply the transform
        (image, label) = self.fashion_mnist.__getitem__(index)
        image = self.transform(image)
        print(type(image))
        return image, label

class Cub(data.Dataset):
    def __init__(self, stage=0):
        self.path = "/private/home/yilundu/sandbox/data/CUB/images/*/*.jpg"
        self.images = glob.glob(self.path)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, index):
        im_path = self.images[index]
        im = imread(im_path)
        im = imresize(im, (64, 64))[:, :, :3]
        im = im / 255.

        im = torch.Tensor(im).permute(2, 0, 1)

        return im, index


class Nvidia(data.Dataset):
    def __init__(self, stage=0, filter_light=False):
        self.path = "/data/vision/billf/scratch/yilundu/dataset/disentanglement/Falcor3D_down128/images/{:06}.png"
        self.labels = np.load("/data/vision/billf/scratch/yilundu/dataset/disentanglement/Falcor3D_down128/train-rec.labels")
        label_mask = (self.labels[:, 0] > 0) & (self.labels[:, 0] < 1)
        idxs = np.arange(self.labels.shape[0])

        self.filter_light = filter_light

        # if self.filter_light:
        #     self.idxs = idxs[label_mask]
        # else:
        self.idxs = idxs

    def __len__(self):
        return self.idxs.shape[0]

    def __getitem__(self, index):
        index = self.idxs[index]
        im_path = self.path.format(index)
        # im_path = self.images[index]
        im = imread(im_path)
        im = imresize(im, (128, 128))[:, :, :3][:, :, ::-1].copy()
        im = im

        im = torch.Tensor(im).permute(2, 0, 1)

        return im, index


class NvidiaDisentangle(data.Dataset):
    def __init__(self, stage=0, filter_light=True):
        self.path = "/data/vision/billf/scratch/yilundu/dataset/disentanglement/Falcor3D_down128/images/{:06}.png"
        self.labels = np.load("/data/vision/billf/scratch/yilundu/dataset/disentanglement/Falcor3D_down128/train-rec.labels")
        idxs = np.arange(self.labels.shape[0])
        self.idxs = idxs

    def __len__(self):
        return self.idxs.shape[0]

    def __getitem__(self, index):
        index = self.idxs[index]
        im_path = self.path.format(index)
        # im_path = self.images[index]
        im = imread(im_path)
        im = imresize(im, (128, 128))[:, :, :3]
        im = im

        # label = int(self.labels[index, 0] * 5)
        label = self.labels[index, 1:]
        im = torch.Tensor(im).permute(2, 0, 1)

        return im, label

class Clevr(data.Dataset):
    def __init__(self, stage=0):
        #self.path = "/data/vision/billf/scratch/yilundu/dataset/clevr/images_clevr/*.png"
        self.path = "/content/images_clevr/*.png"
        self.images = sorted(glob(self.path))

    def __len__(self):
        return len(self.images)

    def __getitem__(self, index):
        im_path = self.images[index]
        im = imread(im_path)
        im = imresize(im, (64, 64))[:, :, :3]

        im = torch.Tensor(im).permute(2, 0, 1)

        return im, index


class ClevrLighting(data.Dataset):
    def __init__(self, stage=0):
        self.path = "/data/vision/billf/scratch/yilundu/dataset/clevr_lighting/images_large_lighting/*.png"
        self.images = sorted(glob(self.path))

    def __len__(self):
        return len(self.images)

    def __getitem__(self, index):
        im_path = self.images[index]
        im = imread(im_path)
        im = imresize(im, (64, 64))[:, :, :3]

        im = torch.Tensor(im).permute(2, 0, 1)

        return im, index


class Exercise(data.Dataset):
    def __init__(self, args):
        self.temporal = args.temporal
        self.path = "/private/home/yilundu/sandbox/data/release_data_set/images/*_im1.png"
        self.images = glob(self.path)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, index):
        try:
            im_path = self.images[index]
            im_path_next = im_path.replace("im1", "im2")
            im = imread(im_path)
            im_next = imread(im_path_next)
            im = imresize(im, (64, 64))[:, :, :3]
            im_next = imresize(im_next, (64, 64))[:, :, :3]

            im = torch.Tensor(im).permute(2, 0, 1)
            im_next = torch.Tensor(im_next).permute(2, 0, 1)

            if self.temporal:
                im = torch.stack([im, im_next], dim=0)

            return im, index
        except:
            return self.__getitem__((index + 1) % len(self.images))


class CelebaHQ(data.Dataset):
    def __init__(self, resolution=64):
        self.name = 'celebahq'
        self.channels = 3
        self.paths = glob("/data/vision/billf/scratch/yilundu/dataset/celebahq/data128x128/*.jpg")
        self.resolution = resolution

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, index):
        path = self.paths[index]
        frame = imread(path)
        frame = imresize(frame, (self.resolution, self.resolution))[:, :, :3]

        im = torch.Tensor(frame).permute(2, 0, 1)

        return im, index


class Airplane(data.Dataset):
    def __init__(self, stage=0):
        # self.path = "/private/home/yilundu/sandbox/video_ebm/dataset/images/*.png"
        self.name = 'celebahq'
        self.channels = 3
        # self.path = "/datasets01/celebAHQ/081318/imgHQ{:05}.npy"
        self.paths = glob("/data/vision/billf/scratch/yilundu/nerf-pytorch/large_render/*.png")

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, index):
        path = self.paths[index]
        frame = imread(path)
        frame = imresize(frame, (64, 64))[:, :, :3]

        im = torch.Tensor(frame).permute(2, 0, 1)

        return im, index

class Anime(data.Dataset):
    def __init__(self, stage=0):
        # self.path = "/private/home/yilundu/sandbox/video_ebm/dataset/images/*.png"
        self.name = 'celebahq'
        self.channels = 3
        # self.path = "/datasets01/celebAHQ/081318/imgHQ{:05}.npy"
        anime_paths = sorted(glob("/data/vision/billf/scratch/yilundu/dataset/anime/cropped/*.jpg"))[:30000]
        self.paths = anime_paths

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, index):
        try:
            path = self.paths[index]
            frame = imread(path)
            frame = cv2.resize(frame, (64, 64), interpolation=cv2.INTER_AREA)

            im = torch.Tensor(frame).permute(2, 0, 1) / 255.

            return im, index
        except:
            ix = random.randint(0, len(self.paths) - 1)
            return self.__getitem__(ix)


class Faces(data.Dataset):
    def __init__(self, stage=0):
        # self.path = "/private/home/yilundu/sandbox/video_ebm/dataset/images/*.png"
        self.name = 'celebahq'
        self.channels = 3
        # self.path = "/datasets01/celebAHQ/081318/imgHQ{:05}.npy"
        paths = sorted(glob("/data/vision/billf/scratch/yilundu/dataset/celebahq/data128x128/*.jpg"))
        anime_paths = sorted(glob("/data/vision/billf/scratch/yilundu/dataset/anime/cropped/*.jpg"))[:30000]
        paths = list(paths) + anime_paths
        random.shuffle(paths)
        self.paths = paths

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, index):
        try:
            path = self.paths[index]
            frame = imread(path)
            frame = cv2.resize(frame, (64, 64), interpolation=cv2.INTER_AREA)

            im = torch.Tensor(frame).permute(2, 0, 1) / 255.

            return im, index
        except:
            ix = random.randint(0, len(self.paths) - 1)
            return self.__getitem__(ix)


class DSprites(data.Dataset):
    """Constructs a dataset with N circles, N is the number of components set by flags"""

    def __init__(self, opt):
        """Initialize this dataset class.

        Parameters:
            opt (Option class) -- stores all the experiment flags; needs to be a subclass of BaseOptions
        """
        self.opt = opt
        self.components = opt.components
        self.data = np.load("dsprites_ndarray_co1sh3sc6or40x32y32_64x64.npz")['imgs']
        self.n = self.data.shape[0]

    def __getitem__(self, index):
        """Return a data point and its metadata information.

        Parameters:
            index - - a random integer for data indexing

        Returns a dictionary that contains A and A_paths
            A(tensor) - - an image in one domain
            A_paths(str) - - the path of the image
        """

        A = np.zeros((3, 64, 64))
        ix = random.randint(0, self.n-1)
        im = self.data[ix]
        for i in range(3):
            A[i] = im

        A = torch.Tensor(A)

        return A, index

    def __len__(self):
        """Return the total number of images in the dataset."""
        # Dataset is always randomly generated
        return 100000

class MultiDspritesLoader():

    def __init__(self, batchsize):
        tf_records_path = 'dataset/multi_dsprites_colored_on_colored.tfrecords'
        batch_size = batchsize

        dataset = multi_dsprites.dataset(tf_records_path, 'colored_on_colored')
        batched_dataset = dataset.batch(batch_size)  # optional batching
        iterator = batched_dataset.make_one_shot_iterator()
        self.data = iterator.get_next()
        self.sess = tf.InteractiveSession()

    def __iter__(self):
        return self

    def __next__(self):
        d = self.sess.run(self.data)
        img = d['image']
        img = img.transpose((0, 3, 1, 2))
        img = img / 255.
        img = torch.Tensor(img)

        return img, torch.ones(1)

    def __len__(self):
        return 1e6


class TetrominoesLoader():

    def __init__(self, batchsize):
        # tf_records_path = '/home/yilundu/my_repos/dataset/tetrominoes_train.tfrecords'
        tf_records_path = '/home/gridsan/yilundu/my_files/ebm_video/dataset/tetrominoes_train.tfrecords'
        batch_size = batchsize

        dataset = tetrominoes.dataset(tf_records_path)
        batched_dataset = dataset.batch(batch_size)  # optional batching
        iterator = batched_dataset.make_one_shot_iterator()
        self.data = iterator.get_next()
        config = tf.ConfigProto(
                device_count = {'GPU': 0}
            )
        self.sess = tf.InteractiveSession(config=config)

    def __iter__(self):
        return self

    def __next__(self):
        d = self.sess.run(self.data)
        img = d['image']
        img = img.transpose((0, 3, 1, 2))
        img = img / 255.
        img = torch.Tensor(img).contiguous()

        return img, torch.ones(1)

    def __len__(self):
        return 1e6

class TFImagenetLoader(data.Dataset):

    def __init__(self, split, batchsize, idx, num_workers, return_label=False):
        IMAGENET_NUM_TRAIN_IMAGES = 1281167
        IMAGENET_NUM_VAL_IMAGES = 50000
        self.return_label = return_label

        if split == "train":
            im_length = IMAGENET_NUM_TRAIN_IMAGES
        else:
            im_length = IMAGENET_NUM_VAL_IMAGES

        self.curr_sample = 0

        index_path = osp.join('/data/vision/billf/scratch/yilundu/imagenet', 'index.json')
        with open(index_path) as f:
            metadata = json.load(f)
            counts = metadata['record_counts']

        if split == 'train':
            files = list(sorted([x for x in counts.keys() if x.startswith('train')]))
        else:
            files = list(sorted([x for x in counts.keys() if x.startswith('validation')]))

        files = [osp.join('/data/vision/billf/scratch/yilundu/imagenet', x) for x in files]
        preprocess_function = ImagenetPreprocessor(224, dtype=tf.float32, train=False).parse_and_preprocess

        ds = tf.data.TFRecordDataset.from_generator(lambda: files, output_types=tf.string)
        ds = ds.apply(tf.data.TFRecordDataset)
        ds = ds.take(im_length)
        # ds = ds.prefetch(buffer_size=4)
        ds = ds.apply(tf.contrib.data.shuffle_and_repeat(buffer_size=10000))
        ds = ds.apply(batching.map_and_batch(map_func=preprocess_function, batch_size=batchsize, num_parallel_batches=4))
        ds = ds.prefetch(buffer_size=2)

        ds_iterator = ds.make_initializable_iterator()
        labels, images = ds_iterator.get_next()
        self.images = tf.clip_by_value(images / 256 + tf.random_uniform(tf.shape(images), 0, 1. / 256), 0.0, 1.0)
        self.labels = labels

        config = tf.ConfigProto(device_count = {'GPU': 0})
        sess = tf.Session(config=config)
        sess.run(ds_iterator.initializer)

        # self.im_length = im_length // batchsize
        self.im_length = im_length

        self.sess = sess

    def __next__(self):
        self.curr_sample += 1

        sess = self.sess

        label, im = sess.run([self.labels, self.images])
        label = label.squeeze() - 1
        im = torch.from_numpy(im).permute((0, 3, 1, 2))
        label = torch.LongTensor(label)

        if self.return_label:
            return im, label
        else:
            return im[:, None, :]

    def __iter__(self):
        return self

    def __len__(self):
        return self.im_length


class TFTaskAdaptation(data.Dataset):

    def __init__(self, split, batchsize):
        data_params = {
            # "dataset": "data." + "clevr(task='count_all')",
            "dataset": "data." + "svhn()",
            "dataset_train_split_name": "trainval",
            "dataset_eval_split_name": "test",
            "shuffle_buffer_size": 10000,
            "prefetch": True,
            "train_examples": None,
            "batch_size": batchsize,
            "batch_size_eval": batchsize,
            "data_for_eval": split == "test",
            "data_dir": "/private/home/yilundu/tensorflow_datasets",
            "input_range": [0.0, 1.0]
        }
        ds = build_data_pipeline(data_params, split)
        ds = ds({'batch_size': batchsize})
        # ds = ds.apply(tf.contrib.data.shuffle_and_repeat(buffer_size=10000))
        # ds = ds.apply(batching.map_and_batch(map_func=preprocess_function, batch_size=FLAGS.batch_size, num_parallel_batches=4))
        # ds = ds.prefetch(buffer_size=2)

        ds_iterator = tf.data.make_initializable_iterator(ds)
        outputs = ds_iterator.get_next()
        image, label = outputs['image'], outputs['label']
        self.images = image
        self.labels = label
        self.split = split

        config = tf.ConfigProto(device_count = {'GPU': 0})
        sess = tf.Session(config=config)
        sess.run(ds_iterator.initializer)

        self.im_length = 1000
        self.curr_sample = 0

        self.sess = sess

    def __next__(self):
        self.curr_sample += 1

        sess = self.sess
        label, im = sess.run([self.labels, self.images])

        if self.split == "train":
            im = im[:, 0].transpose((0, 1, 4, 2, 3))
        else:
            im = im.transpose((0, 3, 1, 2))

        if self.curr_sample == 1000:
            self.curr_sample = 0
            raise StopIteration

        return [torch.Tensor(im[:]), torch.Tensor(label).long()]

    def __iter__(self):
        return self

    def __len__(self):
        return self.im_length

class CubesColor(data.Dataset):
    """Constructs a dataset with N circles, N is the number of components set by flags"""

    def __init__(self, opt, return_label=False, train=True):
        """Initialize this dataset class.

        Parameters:
            opt (Option class) -- stores all the experiment flags; needs to be a subclass of BaseOptions
        """
        self.data = np.load("/private/home/yilundu/dataset/cubes_varied_position_812.npz")
        self.ims = np.array(self.data['ims'])
        self.labels = np.array(self.data['labels'])
        self.return_label = return_label
        self.opt = opt

        n = self.ims.shape[0]
        split_idx = int(0.9 * n)

        if train:
            self.ims = self.ims[:split_idx]
            self.labels = self.labels[:split_idx]
        else:
            self.ims = self.ims[split_idx:]
            self.labels = self.labels[split_idx:]


    def __getitem__(self, index):
        """Return a data point and its metadata information.

        Parameters:
            index - - a random integer for data indexing

        Returns a dictionary that contains A and A_paths
            A(tensor) - - an image in one domain
            A_paths(str) - - the path of the image
        """
        opt = self.opt

        im = np.array(self.ims[index])
        label = torch.FloatTensor(np.array(self.labels[index]))
        im = imresize(im, (opt.im_size, opt.im_size))
        s = im.shape
        im = im.transpose((2, 0, 1)) / 256 + np.random.uniform(0, 1, (s[2], s[0], s[1])) / 256
        im = torch.FloatTensor(im[None, :])

        if self.return_label:
            return im, label
        else:
            return im

    def __len__(self):
        """Return the total number of images in the dataset."""
        # Dataset is always randomly generated
        return self.ims.shape[0]


class CubesColorPair(data.Dataset):
    """Constructs a dataset with N circles, N is the number of components set by flags"""

    def __init__(self, opt, return_label=False, train=True):
        """Initialize this dataset class.

        Parameters:
            opt (Option class) -- stores all the experiment flags; needs to be a subclass of BaseOptions
        """
        self.data = np.load("/private/home/yilundu/dataset/cubes_varied_multi_311.npz")
        self.ims = np.array(self.data['ims'])
        self.labels = np.array(self.data['labels'])
        self.return_label = return_label
        self.opt = opt

        n = self.ims.shape[0]
        split_idx = int(0.9 * n)

        if train:
            self.ims = self.ims[:split_idx]
            self.labels = self.labels[:split_idx]
        else:
            self.ims = self.ims[split_idx:]
            self.labels = self.labels[split_idx:]


    def __getitem__(self, index):
        """Return a data point and its metadata information.

        Parameters:
            index - - a random integer for data indexing

        Returns a dictionary that contains A and A_paths
            A(tensor) - - an image in one domain
            A_paths(str) - - the path of the image
        """
        opt = self.opt

        im = self.ims[index]
        label = np.array(self.labels[index])
        im = imresize(im, (opt.im_size, opt.im_size))
        s = im.shape
        im = im.transpose((2, 0, 1)) / 256 + np.random.uniform(0, 1, (s[2], s[0], s[1])) / 256
        im = torch.Tensor(im[None, :])

        if self.return_label:
            return im, label
        else:
            return im

    def __len__(self):
        """Return the total number of images in the dataset."""
        # Dataset is always randomly generated
        return self.ims.shape[0]


class Kitti(data.Dataset):
    """Constructs a dataset with N circles, N is the number of components set by flags"""

    def __init__(self, opt, return_label=False, train=True):
        """Initialize this dataset class.

        Parameters:
            opt (Option class) -- stores all the experiment flags; needs to be a subclass of BaseOptions
        """
        ims = sorted(glob("/data/vision/billf/scratch/yilundu/dataset/kitti/training/image_02/*/*.png"))
        virtual_ims = sorted(glob("/data/vision/billf/scratch/yilundu/dataset/kitti/virtual_kitti/*/*/frames/rgb/Camera_0/*.jpg"))

        ims = ims * 3 + virtual_ims
        self.ims = ims
        self.opt = opt

    def __getitem__(self, index):
        """Return a data point and its metadata information.

        Parameters:
            index - - a random integer for data indexing

        Returns a dictionary that contains A and A_paths
            A(tensor) - - an image in one domain
            A_paths(str) - - the path of the image
        """
        # 433 - 808
        im = self.ims[index]
        im = imread(im)
        im = im[:, 433:808, :]
        im = imresize(im, (64, 64))[:, :, :3]

        im = torch.Tensor(im).permute(2, 0, 1)

        return im, index

    def __len__(self):
        """Return the total number of images in the dataset."""
        # Dataset is always randomly generated
        return len(self.ims)


class VirtualKitti(data.Dataset):
    """Constructs a dataset with N circles, N is the number of components set by flags"""

    def __init__(self,return_label=False, train=True):
        """Initialize this dataset class.

        Parameters:
            opt (Option class) -- stores all the experiment flags; needs to be a subclass of BaseOptions
        """
        ims = sorted(glob("/data/vision/billf/scratch/yilundu/dataset/kitti/training/image_02/*/*.png"))
        virtual_ims = sorted(glob("/data/vision/billf/scratch/yilundu/dataset/kitti/virtual_kitti/*/*/frames/rgb/Camera_0/*.jpg"))

        self.ims = virtual_ims

    def __getitem__(self, index):
        """Return a data point and its metadata information.

        Parameters:
            index - - a random integer for data indexing

        Returns a dictionary that contains A and A_paths
            A(tensor) - - an image in one domain
            A_paths(str) - - the path of the image
        """
        # 433 - 808
        im = self.ims[index]
        im = imread(im)
        im = im[:, 433:808, :]
        im = imresize(im, (64, 64))[:, :, :3]

        im = torch.Tensor(im).permute(2, 0, 1)

        return im, index

    def __len__(self):
        """Return the total number of images in the dataset."""
        # Dataset is always randomly generated
        return len(self.ims)


class KittiLabel(data.Dataset):
    """Constructs a dataset with N circles, N is the number of components set by flags"""

    def __init__(self,return_label=False, train=True):
        """Initialize this dataset class.

        Parameters:
            opt (Option class) -- stores all the experiment flags; needs to be a subclass of BaseOptions
        """
        virtual_ims = sorted(glob("/data/vision/billf/scratch/yilundu/dataset/kitti/virtual_kitti/*/*/frames/rgb/Camera_0/*.jpg"))
        self.labels = ['fog', 'morning', 'overcast', 'rain', 'sunset']
        self.ims = virtual_ims

    def __getitem__(self, index):
        """Return a data point and its metadata information.

        Parameters:
            index - - a random integer for data indexing

        Returns a dictionary that contains A and A_paths
            A(tensor) - - an image in one domain
            A_paths(str) - - the path of the image
        """
        # 433 - 808
        try:
            im_path = self.ims[index]
            label_id = im_path.split("/")[-5]
            label_id = self.labels.index(label_id)

            im = imread(im_path)

            im = im[:, 433:808, :]
            im = imresize(im, (64, 64))[:, :, :3]

            im = torch.Tensor(im).permute(2, 0, 1)

            return im, label_id
        except:
            return self.__getitem__(random.randint(0, len(self.ims) - 1))

    def __len__(self):
        """Return the total number of images in the dataset."""
        # Dataset is always randomly generated
        return len(self.ims)


class RealKittiLabel(data.Dataset):
    """Constructs a dataset with N circles, N is the number of components set by flags"""

    def __init__(self,return_label=False, train=True):
        """Initialize this dataset class.

        Parameters:
            opt (Option class) -- stores all the experiment flags; needs to be a subclass of BaseOptions
        """
        ims = sorted(glob("/data/vision/billf/scratch/yilundu/dataset/kitti/training/image_02/*/*.png"))

        self.ims = ims

    def __getitem__(self, index):
        """Return a data point and its metadata information.

        Parameters:
            index - - a random integer for data indexing

        Returns a dictionary that contains A and A_paths
            A(tensor) - - an image in one domain
            A_paths(str) - - the path of the image
        """
        # 433 - 808
        im_path = self.ims[index]
        im = imread(im_path)
        im = im[:, 433:808, :]
        im = imresize(im, (64, 64))[:, :, :3]

        im = torch.Tensor(im).permute(2, 0, 1)

        return im, 0

    def __len__(self):
        """Return the total number of images in the dataset."""
        # Dataset is always randomly generated
        return len(self.ims)


class RealKitti(data.Dataset):
    """Constructs a dataset with N circles, N is the number of components set by flags"""

    def __init__(self,return_label=False, train=True):
        """Initialize this dataset class.

        Parameters:
            opt (Option class) -- stores all the experiment flags; needs to be a subclass of BaseOptions
        """
        ims = sorted(glob("/data/vision/billf/scratch/yilundu/dataset/kitti/training/image_02/*/*.png"))

        self.ims = ims

    def __getitem__(self, index):
        """Return a data point and its metadata information.

        Parameters:
            index - - a random integer for data indexing

        Returns a dictionary that contains A and A_paths
            A(tensor) - - an image in one domain
            A_paths(str) - - the path of the image
        """
        # 433 - 808
        im = self.ims[index]
        im = imread(im)
        im = im[:, 433:808, :]
        im = imresize(im, (64, 64))[:, :, :3]

        im = torch.Tensor(im).permute(2, 0, 1)

        return im, index

    def __len__(self):
        """Return the total number of images in the dataset."""
        # Dataset is always randomly generated
        return len(self.ims)

if __name__ == "__main__":
    loader = Kitti(None)
    # for data in loader:
    #     print("here")

# %%
import torch
#from models import LatentEBM, ToyEBM, BetaVAE_H, LatentEBM128
from tensorflow.python.platform import flags
import torch.nn.functional as F
import os
#from dataset import IntPhysDataset, ToyDataset, TFImagenetLoader, CubesColor, CubesColorPair, TFTaskAdaptation, DSprites, Blender, Cub, Nvidia, Clevr, Exercise, CelebaHQ, Kitti, Airplane, Faces, ClevrLighting
import torch.multiprocessing as mp
import torch.distributed as dist
from torch.optim import Adam
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import DataLoader
from easydict import EasyDict
import os.path as osp
from torch.nn.utils import clip_grad_norm
import numpy as np
from imageio import imwrite
import cv2
import argparse
import pdb
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
from torch.nn.parallel.distributed import DistributedDataParallel as DDP
import torch.backends.cudnn as cudnn
import random
from torchvision.utils import make_grid
#from dataset import MultiDspritesLoader, TetrominoesLoader
from imageio import get_writer


"""Parse input arguments"""
parser = argparse.ArgumentParser(description='Train EBM model')


parser.add_argument('--train', action='store_true', help='whether or not to train')
parser.add_argument('--optimize_test', action='store_true', help='whether or not to train')
parser.add_argument('--cuda', action='store_true', help='whether to use cuda or not')
parser.add_argument('--single', action='store_true', help='test overfitting of the dataset')


parser.add_argument('--dataset', default='blender', type=str, help='Dataset to use (intphys or others or imagenet or cubes)')
parser.add_argument('--logdir', default='cachedir', type=str, help='location where log of experiments will be stored')
parser.add_argument('--exp', default='default', type=str, help='name of experiments')

# training
parser.add_argument('--resume_iter', default=0, type=int, help='iteration to resume training')
parser.add_argument('--batch_size', default=64, type=int, help='size of batch of input to use')
parser.add_argument('--num_epoch', default=10000, type=int, help='number of epochs of training to run')
parser.add_argument('--lr', default=1e-4, type=float, help='learning rate for training')
parser.add_argument('--log_interval', default=10, type=int, help='log outputs every so many batches')
parser.add_argument('--save_interval', default=1000, type=int, help='save outputs every so many batches')

# data
parser.add_argument('--data_workers', default=4, type=int, help='Number of different data workers to load data in parallel')
parser.add_argument('--ensembles', default=1, type=int, help='use an ensemble of models')
parser.add_argument('--vae-beta', type=float, default=0.)

# EBM specific settings

# Model specific settings
parser.add_argument('--filter_dim', default=64, type=int, help='number of filters to use')
parser.add_argument('--components', default=2, type=int, help='number of components to explain an image with')
parser.add_argument('--component_weight', action='store_true', help='optimize for weights of the components also')
parser.add_argument('--tie_weight', action='store_true', help='tie the weights between seperate models')
parser.add_argument('--optimize_mask', action='store_true', help='also optimize a segmentation mask over image')
parser.add_argument('--recurrent_model', action='store_true', help='use a recurrent model to infer latents')
parser.add_argument('--pos_embed', action='store_true', help='add a positional embedding to model')
parser.add_argument('--spatial_feat', action='store_true', help='use spatial latents for object segmentation')


parser.add_argument('--num_steps', default=10, type=int, help='Steps of gradient descent for training')
parser.add_argument('--num_visuals', default=16, type=int, help='Number of visuals')
parser.add_argument('--num_additional', default=0, type=int, help='Number of additional components to add')

parser.add_argument('--step_lr', default=500.0, type=float, help='step size of latents')

parser.add_argument('--latent_dim', default=64, type=int, help='dimension of the latent')
parser.add_argument('--sample', action='store_true', help='generate negative samples through Langevin')
parser.add_argument('--decoder', action='store_true', help='decoder for model')

# Distributed training hyperparameters
parser.add_argument('--nodes', default=1, type=int, help='number of nodes for training')
parser.add_argument('--gpus', default=1, type=int, help='number of gpus per nodes')
parser.add_argument('--node_rank', default=0, type=int, help='rank of node')



def average_gradients(models):
    size = float(dist.get_world_size())

    for model in models:
        for name, param in model.named_parameters():
            if param.grad is None:
                continue

            dist.all_reduce(param.grad.data, op=dist.reduce_op.SUM)
            param.grad.data /= size


def gen_image(latents, FLAGS, models, im_neg, im, num_steps, sample=False, create_graph=True, idx=None, weights=None):
    im_noise = torch.randn_like(im_neg).detach()
    im_negs_samples = []

    im_negs = []

    latents = torch.stack(latents, dim=0)

    if FLAGS.decoder:
        masks = []
        colors = []
        for i in range(len(latents)):
            if idx is not None and idx != i:
                pass
            else:
                color, mask = models[i % FLAGS.components].forward(None, latents[i])
                masks.append(mask)
                colors.append(color)
        masks = F.softmax(torch.stack(masks, dim=1), dim=1)
        colors = torch.stack(colors, dim=1)
        im_neg = torch.sum(masks * colors, dim=1)
        im_negs = [im_neg]
        im_grad = torch.zeros_like(im_neg)
    else:
        im_neg.requires_grad_(requires_grad=True)
        s = im.size()
        masks = torch.zeros(s[0], FLAGS.components, s[-2], s[-1]).to(im_neg.device)
        masks.requires_grad_(requires_grad=True)

        for i in range(num_steps):
            im_noise.normal_()

            energy = 0
            for j in range(len(latents)):
                if idx is not None and idx != j:
                    pass
                else:
                    ix = j % FLAGS.components
                    energy = models[j % FLAGS.components].forward(im_neg, latents[j]) + energy

            im_grad, = torch.autograd.grad([energy.sum()], [im_neg], create_graph=create_graph)

            im_neg = im_neg - FLAGS.step_lr * im_grad

            latents = latents

            im_neg = torch.clamp(im_neg, 0, 1)
            im_negs.append(im_neg)
            im_neg = im_neg.detach()
            im_neg.requires_grad_()

    return im_neg, im_negs, im_grad, masks


def ema_model(models, models_ema, mu=0.999):
    for (model, model_ema) in zip(models, models_ema):
        for param, param_ema in zip(model.parameters(), model_ema.parameters()):
            param_ema.data[:] = mu * param_ema.data + (1 - mu) * param.data


def sync_model(models):
    size = float(dist.get_world_size())

    for model in models:
        for param in model.parameters():
            dist.broadcast(param.data, 0)


def init_model(FLAGS, device, dataset):
    if FLAGS.tie_weight:
        if FLAGS.dataset == "toy":
            model = ToyEBM(FLAGS, dataset).to(device)
        else:
            if FLAGS.vae_beta:
                model = BetaVAE_H(z_dim=FLAGS.latent_dim, nc=3).to(device)
                FLAGS.ensembles = 1
                FLAGS.components = 1
            else:
                if FLAGS.dataset == "celebahq_128":
                    model = LatentEBM128(FLAGS, dataset).to(device)
                else:
                    model = LatentEBM(FLAGS, dataset).to(device)

        models = [model for i in range(FLAGS.ensembles)]
        optimizers = [Adam(model.parameters(), lr=FLAGS.lr)]
    else:
        models = [LatentEBM(FLAGS, dataset).to(device) for i in range(FLAGS.ensembles)]

        optimizers = [Adam(model.parameters(), lr=FLAGS.lr) for model in models]

    return models, optimizers


def test(train_dataloader, models, FLAGS, step=0):
    if FLAGS.cuda:
        dev = torch.device("cuda")
    else:
        dev = torch.device("cpu")

    replay_buffer = None

    [model.eval() for model in models]
    for im, idx in train_dataloader:

        im = im.to(dev)
        idx = idx.to(dev)
        im = im[:FLAGS.num_visuals]
        idx = idx[:FLAGS.num_visuals]
        batch_size = im.size(0)
        latent = models[0].embed_latent(im)

        latents = torch.chunk(latent, FLAGS.components, dim=1)

        im_init = torch.rand_like(im)
        assert len(latents) == FLAGS.components
        im_neg, _, im_grad, mask = gen_image(latents, FLAGS, models, im_init, im, FLAGS.num_steps, sample=FLAGS.sample,
                                       create_graph=False)
        im_neg = im_neg.detach()
        im_components = []

        if FLAGS.components > 1:
            for i, latent in enumerate(latents):
                im_init = torch.rand_like(im)
                latents_select = latents[i:i+1]
                im_component, _, _, _ = gen_image(latents_select, FLAGS, models, im_init, im, FLAGS.num_steps, sample=FLAGS.sample,
                                           create_graph=False)
                im_components.append(im_component)

            im_init = torch.rand_like(im)
            latents_perm = [torch.cat([latent[i:], latent[:i]], dim=0) for i, latent in enumerate(latents)]
            im_neg_perm, _, im_grad_perm, _ = gen_image(latents_perm, FLAGS, models, im_init, im, FLAGS.num_steps, sample=FLAGS.sample,
                                                     create_graph=False)
            im_neg_perm = im_neg_perm.detach()
            im_init = torch.rand_like(im)
            add_latents = list(latents)
            for i in range(FLAGS.num_additional):
                add_latents.append(torch.roll(latents[i], i + 1, 0))
            im_neg_additional, _, _, _ = gen_image(tuple(add_latents), FLAGS, models, im_init, im, FLAGS.num_steps, sample=FLAGS.sample,
                                                     create_graph=False)

        im.requires_grad = True
        im_grads = []

        for i, latent in enumerate(latents):
            if FLAGS.decoder:
                im_grad = torch.zeros_like(im)
            else:
                energy_pos = models[i].forward(im, latents[i])
                im_grad = torch.autograd.grad([energy_pos.sum()], [im])[0]
            im_grads.append(im_grad)

        im_grad = torch.stack(im_grads, dim=1)

        s = im.size()
        im_size = s[-1]

        im_grad = im_grad.view(batch_size, FLAGS.components, 3, im_size, im_size) # [4, 3, 3, 128, 128]
        im_grad_dense = im_grad.view(batch_size, FLAGS.components, 1, 3 * im_size * im_size, 1) # [4, 3, 1, 49152, 1]
        im_grad_min = im_grad_dense.min(dim=3, keepdim=True)[0]
        im_grad_max = im_grad_dense.max(dim=3, keepdim=True)[0] # [4, 3, 1, 1, 1]


        im_grad = (im_grad - im_grad_min) / (im_grad_max - im_grad_min + 1e-5) # [4, 3, 3, 128, 128]
        im_grad[:, :, :, :1, :] = 1
        im_grad[:, :, :, -1:, :] = 1
        im_grad[:, :, :, :, :1] = 1
        im_grad[:, :, :, :, -1:] = 1
        im_output = im_grad.permute(0, 3, 1, 4, 2).reshape(batch_size * im_size, FLAGS.components * im_size, 3)
        im_output = im_output.cpu().detach().numpy() * 100

        im_output = (im_output - im_output.min()) / (im_output.max() - im_output.min())

        im = im.cpu().detach().numpy().transpose((0, 2, 3, 1)).reshape(batch_size*im_size, im_size, 3)

        im_output = np.concatenate([im_output, im], axis=1)
        im_output = (im_output*255).astype(np.uint8)
        imwrite("result/%s/s%08d_grad.png" % (FLAGS.exp,step), im_output)

        im_neg = im_neg_tensor = im_neg.detach().cpu()
        im_components = [im_components[i].detach().cpu() for i in range(len(im_components))]
        im_neg = torch.cat([im_neg] + im_components)
        im_neg = np.clip(im_neg, 0.0, 1.0)
        im_neg = make_grid(im_neg, nrow=int(im_neg.shape[0] / (FLAGS.components + 1))).permute(1, 2, 0)
        im_neg = (im_neg.numpy()*255).astype(np.uint8)
        imwrite("result/%s/s%08d_gen.png" % (FLAGS.exp,step), im_neg)

        if FLAGS.components > 1:
            im_neg_perm = im_neg_perm.detach().cpu()
            im_components_perm = []
            for i,im_component in enumerate(im_components):
                im_components_perm.append(torch.cat([im_component[i:], im_component[:i]]))
            im_neg_perm = torch.cat([im_neg_perm] + im_components_perm)
            im_neg_perm = np.clip(im_neg_perm, 0.0, 1.0)
            im_neg_perm = make_grid(im_neg_perm, nrow=int(im_neg_perm.shape[0] / (FLAGS.components + 1))).permute(1, 2, 0)
            im_neg_perm = (im_neg_perm.numpy()*255).astype(np.uint8)
            imwrite("result/%s/s%08d_gen_perm.png" % (FLAGS.exp,step), im_neg_perm)

            im_neg_additional = im_neg_additional.detach().cpu()
            for i in range(FLAGS.num_additional):
                im_components.append(torch.roll(im_components[i], i + 1, 0))
            im_neg_additional = torch.cat([im_neg_additional] + im_components)
            im_neg_additional = np.clip(im_neg_additional, 0.0, 1.0)
            im_neg_additional = make_grid(im_neg_additional,
                                nrow=int(im_neg_additional.shape[0] / (FLAGS.components + FLAGS.num_additional + 1))).permute(1, 2, 0)
            im_neg_additional = (im_neg_additional.numpy()*255).astype(np.uint8)
            imwrite("result/%s/s%08d_gen_add.png" % (FLAGS.exp,step), im_neg_additional)

            print('test at step %d done!' % step)
        break

    [model.train() for model in models]


def train(train_dataloader, test_dataloader, logger, models, optimizers, FLAGS, logdir, rank_idx):
    it = FLAGS.resume_iter
    [optimizer.zero_grad() for optimizer in optimizers]

    dev = torch.device("cuda")

    # Use LPIPS loss for CelebA-HQ 128x128
    if FLAGS.dataset == "celebahq_128":
        import lpips
        loss_fn_vgg = lpips.LPIPS(net='vgg').cuda()

    for epoch in range(FLAGS.num_epoch):
        for im, idx in train_dataloader:

            im = im.to(dev)
            idx = idx.to(dev)
            im_orig = im

            random_idx = random.randint(0, FLAGS.ensembles - 1)
            random_idx = 0

            latent = models[0].embed_latent(im)

            latents = torch.chunk(latent, FLAGS.components, dim=1)

            im_neg = torch.rand_like(im)
            im_neg_init = im_neg

            im_neg, im_negs, im_grad, _ = gen_image(latents, FLAGS, models, im_neg, im, FLAGS.num_steps, FLAGS.sample)

            im_negs = torch.stack(im_negs, dim=1)

            energy_pos = 0
            energy_neg = 0

            energy_poss = []
            energy_negs = []
            for i in range(FLAGS.components):
                energy_poss.append(models[i].forward(im, latents[i]))
                energy_negs.append(models[i].forward(im_neg.detach(), latents[i]))

            energy_pos = torch.stack(energy_poss, dim=1)
            energy_neg = torch.stack(energy_negs, dim=1)
            ml_loss = (energy_pos - energy_neg).mean()

            im_loss = torch.pow(im_negs[:, -1:] - im[:, None], 2).mean()

            if it < 10000 or FLAGS.dataset != "celebahq_128":
                loss = im_loss
            else:
                vgg_loss = loss_fn_vgg(im_negs[:, -1], im).mean()
                loss = vgg_loss  + 0.1 * im_loss

            loss.backward()
            if FLAGS.gpus > 1:
                average_gradients(models)

            [torch.nn.utils.clip_grad_norm_(model.parameters(), 10.0) for model in models]
            [optimizer.step() for optimizer in optimizers]
            [optimizer.zero_grad() for optimizer in optimizers]

            if it % FLAGS.log_interval == 0 and rank_idx == 0:
                loss = loss.item()
                energy_pos_mean = energy_pos.mean().item()
                energy_neg_mean = energy_neg.mean().item()
                energy_pos_std = energy_pos.std().item()
                energy_neg_std = energy_neg.std().item()

                kvs = {}
                kvs['loss'] = loss
                kvs['ml_loss'] = ml_loss.item()
                kvs['im_loss'] = im_loss.item()

                if FLAGS.dataset == "celebahq_128" and ('vgg_loss' in kvs):
                    kvs['vgg_loss'] = vgg_loss.item()

                kvs['energy_pos_mean'] = energy_pos_mean
                kvs['energy_neg_mean'] = energy_neg_mean
                kvs['energy_pos_std'] = energy_pos_std
                kvs['energy_neg_std'] = energy_neg_std
                kvs['average_im_grad'] = torch.abs(im_grad).max()

                string = "Iteration {} ".format(it)

                for k, v in kvs.items():
                    string += "%s: %.6f  " % (k,v)
                    logger.add_scalar(k, v, it)

                print(string)

            if it % FLAGS.save_interval == 0 and rank_idx == 0:
                model_path = osp.join(logdir, "model_{}.pth".format(it))


                ckpt = {'FLAGS': FLAGS}

                for i in range(len(models)):
                    ckpt['model_state_dict_{}'.format(i)] = models[i].state_dict()

                for i in range(len(optimizers)):
                    ckpt['optimizer_state_dict_{}'.format(i)] = optimizers[i].state_dict()

                torch.save(ckpt, model_path)
                print("Saving model in directory....")
                print('run test')

                test(test_dataloader, models, FLAGS, step=it)

            it += 1



def main_single(rank, FLAGS):
    rank_idx = FLAGS.node_rank * FLAGS.gpus + rank
    world_size = FLAGS.nodes * FLAGS.gpus


    if not os.path.exists('result/%s' % FLAGS.exp):
        try:
            os.makedirs('result/%s' % FLAGS.exp)
        except:
            pass

    if FLAGS.dataset == 'cubes':
        dataset = CubesColor(FLAGS, train=True)
        test_dataset = CubesColor(FLAGS, train=False)
    elif FLAGS.dataset == 'cubes_pair':
        dataset = CubesColorPair(FLAGS, train=True)
        test_dataset = CubesColorPair(FLAGS, train=False)
    elif FLAGS.dataset == "nvidia":
        dataset = Nvidia(FLAGS)
        test_dataset = dataset
    elif FLAGS.dataset == "clevr":
        dataset = Clevr(FLAGS)
        test_dataset = dataset
    elif FLAGS.dataset == "clevr_lighting":
        dataset = ClevrLighting(FLAGS)
        test_dataset = dataset
    elif FLAGS.dataset == "exercise":
        dataset = Exercise(FLAGS)
        test_dataset = dataset
    elif FLAGS.dataset == "intphys":
        dataset = IntPhysDataset(FLAGS)
        test_dataset = dataset
    elif FLAGS.dataset == "celebahq":
        dataset = CelebaHQ(resolution=64)
        test_dataset = dataset
    elif FLAGS.dataset == "celebahq_128":
        dataset = CelebaHQ(resolution=128)
        test_dataset = dataset
    elif FLAGS.dataset == "kitti":
        dataset = Kitti(FLAGS)
        test_dataset = dataset
    elif FLAGS.dataset == "faces":
        dataset = Faces(FLAGS)
        test_dataset = dataset
    elif FLAGS.dataset == "fashionmnist":
        dataset = FashionMNIST(root = '/content/sample_data', download = True, transform =  transforms.Compose([transforms.Grayscale(num_output_channels=3), transforms.ToTensor()]))
        test_dataset = dataset
    else:
        dataset = ToyDataset(FLAGS)
        test_dataset = ToyDataset(FLAGS)

    shuffle=True
    sampler = None

    if world_size > 1:
        group = dist.init_process_group(backend='nccl', init_method='tcp://localhost:8113', world_size=world_size, rank=rank_idx, group_name="default")

    torch.cuda.set_device(rank)
    device = torch.device('cuda')

    logdir = osp.join(FLAGS.logdir, FLAGS.exp)
    FLAGS_OLD = FLAGS

    if FLAGS.resume_iter != 0:
        model_path = osp.join(logdir, "model_{}.pth".format(FLAGS.resume_iter))

        checkpoint = torch.load(model_path, map_location=torch.device('cpu'))
        FLAGS = checkpoint['FLAGS']

        FLAGS.resume_iter = FLAGS_OLD.resume_iter
        FLAGS.save_interval = FLAGS_OLD.save_interval
        FLAGS.nodes = FLAGS_OLD.nodes
        FLAGS.gpus = FLAGS_OLD.gpus
        FLAGS.node_rank = FLAGS_OLD.node_rank
        FLAGS.train = FLAGS_OLD.train
        FLAGS.batch_size = FLAGS_OLD.batch_size
        FLAGS.num_visuals = FLAGS_OLD.num_visuals
        FLAGS.num_additional = FLAGS_OLD.num_additional
        FLAGS.decoder = FLAGS_OLD.decoder
        FLAGS.optimize_test = FLAGS_OLD.optimize_test
        FLAGS.temporal = FLAGS_OLD.temporal
        FLAGS.sim = FLAGS_OLD.sim
        FLAGS.exp = FLAGS_OLD.exp
        FLAGS.step_lr = FLAGS_OLD.step_lr
        FLAGS.num_steps = FLAGS_OLD.num_steps
        FLAGS.vae_beta = FLAGS_OLD.vae_beta

        models, optimizers  = init_model(FLAGS, device, dataset)
        state_dict = models[0].state_dict()

        for i, (model, optimizer) in enumerate(zip(models, optimizers)):
            model.load_state_dict(checkpoint['model_state_dict_{}'.format(i)], strict=False)
            optimizer.load_state_dict(checkpoint['optimizer_state_dict_{}'.format(i)], strict=False)

    else:
        models, optimizers = init_model(FLAGS, device, dataset)

    if FLAGS.gpus > 1:
        sync_model(models)

    if FLAGS.dataset == "multidsprites":
        train_dataloader = MultiDspritesLoader(FLAGS.batch_size)
        test_dataloader = MultiDspritesLoader(FLAGS.batch_size)
    elif FLAGS.dataset == "tetris":
        train_dataloader = TetrominoesLoader(FLAGS.batch_size)
        test_dataloader = TetrominoesLoader(FLAGS.batch_size)
    else:
        train_dataloader = DataLoader(dataset, num_workers=FLAGS.data_workers, batch_size=FLAGS.batch_size, shuffle=shuffle, pin_memory=False)
        test_dataloader = DataLoader(test_dataset, num_workers=FLAGS.data_workers, batch_size=FLAGS.num_visuals, shuffle=True, pin_memory=False, drop_last=True)

    logger = SummaryWriter(logdir)
    it = FLAGS.resume_iter

    if FLAGS.train:
        models = [model.train() for model in models]
    else:
        models = [model.eval() for model in models]

    if FLAGS.train:
        train(train_dataloader, test_dataloader, logger, models, optimizers, FLAGS, logdir, rank_idx)

    elif FLAGS.optimize_test:
        test_optimize(test_dataloader, models, FLAGS, step=FLAGS.resume_iter)
    else:
        test(test_dataloader, models, FLAGS, step=FLAGS.resume_iter)

# %%
import easydict
args = easydict.EasyDict({
    "dataset": "imagenet",
    "cuda": True,
})

# %%
FLAGS, _ = parser.parse_known_args()

FLAGS.ensembles = FLAGS.components
FLAGS.tie_weight = True
FLAGS.sample = True
FLAGS.cuda = True
FLAGS.dataset = 'clevr'
FLAGS.train = True
#FLAGS.num_epoch = 1

FLAGS.batch_size = 32
FLAGS.lr = 1e-4

logdir = osp.join(FLAGS.logdir, FLAGS.exp)

if not osp.exists(logdir):
  os.makedirs(logdir)

if FLAGS.gpus > 1:
  mp.spawn(main_single, nprocs=FLAGS.gpus, args=(FLAGS,))
else:
  main_single(0, FLAGS)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# <ipython-input-4-5dd6fa5792e9>:388: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imread(im_path)
# <ipython-input-4-5dd6fa5792e9>:388: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imread(im_path)
# <ipython-input-4-5dd6fa5792e9>:388: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imread(im_path)
# <ipython-input-4-5dd6fa5792e9>:388: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imread(im_path)
# Iteration 0 loss: 0.091789  ml_loss: 0.000190  im_loss: 0.091789  energy_pos_mean: 0.064609  energy_neg_mean: 0.064419  energy_pos_std: 0.004775  energy_neg_std: 0.004778  average_im_grad: 0.000004
# Saving model in directory....
# run test
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# <ipython-input-4-5dd6fa5792e9>:388: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imread(im_path)
# <ipython-input-4-5dd6fa5792e9>:388: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imread(im_path)
# <ipython-input-4-5dd6fa5792e9>:388: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imread(im_path)
# <ipython-input-4-5dd6fa5792e9>:388: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imread(im_path)
